# %%
import json
import pandas as pd
from pathlib import Path
from typing import Dict, Any

# 指定目录和 json 文件
data_dir = Path('.')
json_files = [
    'rebuttal_set_temp_old.json',
    'rebuttal_set_temp_fixed.json'
]

def flatten_dict(d: Dict[str, Any], parent_key: str = '', sep: str = '_') -> Dict[str, Any]:
    """递归展平嵌套字典"""
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# 加载所有 json 文件并解析为 DataFrame
all_data = []

for file in json_files:
    file_path = data_dir / file
    with open(file_path, 'r') as f:
        data = json.load(f)

    # 每个 json 文件的顶层 key 是实验名称，value 是参数字典
    for exp_name, exp_params in data.items():
        flat_params = flatten_dict(exp_params)
        flat_params['experiment_name'] = exp_name  # 保存实验名称
        flat_params['source_file'] = file  # 保存来源文件
        all_data.append(flat_params)

# 转换为 DataFrame
df = pd.DataFrame(all_data)

print(f"✓ 加载完成！共 {len(df)} 行")
print(f"✓ 列数: {len(df.columns)}")
print(f"\n数据源: {json_files}")
print(f"\nDataFrame 形状: {df.shape}")
print(f"\n前几行:")
df.head()
# Out:
# ✓ 加载完成！共 180 行
# ✓ 列数: 112
#
# 数据源: ['rebuttal_set_temp_old.json', 'rebuttal_set_temp_fixed.json']
#
# DataFrame 形状: (180, 112)
#
# 前几行:
#       _runtime  _step    _timestamp  action_dim     alpha  alpha_init  \
# 0  2842.996196    200  1.763519e+09          30  0.503678         0.7
# 1  2687.862297    200  1.763503e+09          30  0.507356         0.9
# 2  5185.882678    200  1.763514e+09          80  0.500000         0.5
# 3  4317.848998    200  1.763492e+09          80  0.507356         0.9
# 4  4442.396480    200  1.763508e+09          80  0.507356         0.9
#
#    alpha_logit  alpha_lr alpha_sched  alpha_train_first_steps  ...  \
# 0     0.014711     0.001    hold_exp                    False  ...
# 1     0.029425     0.001    hold_exp                    False  ...
# 2     0.000000     0.001    hold_exp                    False  ...
# 3     0.029425     0.001    hold_exp                    False  ...
# 4     0.029425     0.001    hold_exp                    False  ...
#
#    use_alpha_scheduler use_exp_weight_decay  use_external_sampling_model  \
# 0                 True                    1                        False
# 1                 True                    1                        False
# 2                 True                    1                        False
# 3                 True                    1                        False
# 4                 True                    1                        False
#
#    use_grad_clip  use_modified_reward  use_replay_buffer   wdb  \
# 0          False                False              False  True
# 1          False                False              False  True
# 2          False                False              False  True
# 3          False                False              False  True
# 4          False                False              False  True
#
#            wdb_group                                    experiment_name  \
# 0  set_temp_rebuttal  ss(2)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(small)_m(...
# 1  set_temp_rebuttal  ss(2)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(small)_m(...
# 2  set_temp_rebuttal  ss(1)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(medium)_m...
# 3  set_temp_rebuttal  ss(1)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(medium)_m...
# 4  set_temp_rebuttal  ss(2)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(medium)_m...
#
#                   source_file
# 0  rebuttal_set_temp_old.json
# 1  rebuttal_set_temp_old.json
# 2  rebuttal_set_temp_old.json
# 3  rebuttal_set_temp_old.json
# 4  rebuttal_set_temp_old.json
#
# [5 rows x 112 columns]

# %%
import re
import numpy as np

# 复制一份以免污染原始 df
df_all = df.copy()

# 解析实验名称中的参数
def parse_exp_name(exp_name: str) -> dict:
    params = {}
    ss_match = re.search(r'ss\((\d+)\)', exp_name)
    if ss_match:
        params['seed'] = int(ss_match.group(1))

    m_match = re.search(r'_m\(([^)]+)\)', exp_name)
    if m_match:
        params['method'] = m_match.group(1)

    # 提取size sz(xxx)
    sz_match = re.search(r'_sz\(([^)]+)\)', exp_name)
    if sz_match:
        params['size'] = sz_match.group(1)

    a_match = re.search(r'_a\(([^)]+)\)', exp_name)
    if a_match:
        try:
            params['alpha_init_from_name'] = float(a_match.group(1))
        except ValueError:
            params['alpha_init_from_name'] = np.nan

    return params

parsed_rows = []
for _, row in df_all.iterrows():
    name = row.get('experiment_name', '')
    parsed = parse_exp_name(name)
    method = parsed.get('method')
    
    # 来自这个文件的method加上"fl-"前缀
    source_file = row.get('source_file', '')
    if source_file in ['refactored_alpha_gfn_set_new_icml.json']:
        if method:
            method = f"fl_{method}"
    
    parsed_rows.append({
        **row,
        'seed': parsed.get('seed'),
        'method': method,
        'size': parsed.get('size'),
        'alpha_init_name': parsed.get('alpha_init_from_name'),
        'alpha': row.get('alpha_init', row.get('alpha'))
    })

df_all = pd.DataFrame(parsed_rows)

# 过滤掉来自 rebuttal_set_fl.json 且 method 为 subtb_gfn 的数据
before_filter = len(df_all)
df_all = df_all[~((df_all['source_file'] == 'rebuttal_set_fl.json') & (df_all['method'] == 'subtb_gfn'))]
after_filter = len(df_all)
if before_filter > after_filter:
    print(f"✓ 已过滤掉 {before_filter - after_filter} 条数据（来自 rebuttal_set_fl.json 且 method=subtb_gfn）\n")

print(f"总实验数: {len(df_all)}")
print(f"Unique seeds: {sorted(df_all['seed'].dropna().unique())}")
print(f"Unique sizes: {sorted(df_all['size'].dropna().unique())}")
print(f"Unique alphas (from alpha_init): {sorted(df_all['alpha'].dropna().unique())}")
print(f"Unique objectives/methods: {sorted(df_all['method'].dropna().unique())}")
print(f"Unique reward_temp labels: {sorted(df_all['reward_temp'].dropna().unique())}")
print("\n数据来源分布:")
print(df_all.groupby(['source_file', 'method', 'size']).size())

# 使用指定的评估指标
metrics = ['modes', 'mean_top_1000_R', 'mean_top_1000_similarity', 'spearman_corr_test']

# 检查哪些指标存在
available_metrics = [m for m in metrics if m in df_all.columns]
missing_metrics = [m for m in metrics if m not in df_all.columns]

if missing_metrics:
    print(f"⚠️ 缺失指标: {missing_metrics}")
    print(f"✓ 可用指标: {available_metrics}\n")
    metrics = available_metrics

objectives = sorted(df_all['method'].dropna().unique())
sizes = sorted(df_all['size'].dropna().unique())
reward_temps = sorted(df_all['reward_temp'].dropna().unique())

print(f"\n{'=' * 80}")
print(f"找到 {len(objectives)} 个 objectives: {objectives}")
print(f"找到 {len(sizes)} 个 sizes: {sizes}")
print(f"找到 {len(reward_temps)} 个 reward_temps: {reward_temps}")
print(f"{'=' * 80}")

# 收集绘图配置
fig_configs = []

for obj in objectives:
    for size in sizes:
        for reward_temp in reward_temps:
            print(f"\n{'=' * 80}")
            print(f"Objective: {obj}, Size: {size}, Reward_temp: {reward_temp}")
            print(f"{'=' * 80}")

            df_obj = df_all[(df_all['method'] == obj) & (df_all['size'] == size) & (df_all['reward_temp'] == reward_temp)].copy()
            if len(df_obj) == 0:
                print("无数据，跳过")
                continue

            print(f"  实验数: {len(df_obj)}")
            print(f"  来源文件: {df_obj['source_file'].unique()}")

            df_averaged = df_obj.groupby('alpha')[metrics].mean().reset_index()
            df_averaged = df_averaged.sort_values('alpha')

            print("\n按 seed 平均后的结果 (基于 alpha_init):")
            print(df_averaged.to_string(index=False))

            print("\n最优 Alpha 分析:")
            print(f"{'-' * 80}")
            for metric in metrics:
                if len(df_averaged) > 0 and not df_averaged[metric].isna().all():
                    best_idx = df_averaged[metric].idxmax()
                    best_alpha = df_averaged.loc[best_idx, 'alpha']
                    best_value = df_averaged.loc[best_idx, metric]
                    print(f"  {metric:30s} -> 最优 alpha_init: {best_alpha:.4f}, 最优值: {best_value:.6f}")

            plot_metrics = [m for m in metrics if not df_averaged[m].isna().all()]
            if plot_metrics:
                fig_configs.append({
                    'method': obj,
                    'size': size,
                    'reward_temp': reward_temp,
                    'data': df_averaged,
                    'metrics': plot_metrics
                })
print(df_all.groupby(['source_file', 'method', 'size', 'reward_temp']).size())
# Out:
# 总实验数: 180
# Unique seeds: [0, 1, 2, 3, 4]
# Unique sizes: ['large', 'medium', 'small']
# Unique alphas (from alpha_init): [0.5, 0.7, 0.8, 0.9]
# Unique objectives/methods: ['db_gfn', 'fl_db_gfn', 'tb_gfn']
# Unique reward_temp labels: [0.5, 1.0, 2.0]
#
# 数据来源分布:
# source_file                   method     size
# rebuttal_set_temp_fixed.json  db_gfn     large     10
#                                          medium    10
#                                          small     10
#                               fl_db_gfn  large     10
#                                          medium    10
#                                          small     10
#                               tb_gfn     large     10
#                                          medium    10
#                                          small     10
# rebuttal_set_temp_old.json    db_gfn     large     10
#                                          medium    10
#                                          small     10
#                               fl_db_gfn  large     10
#                                          medium    10
#                                          small     10
#                               tb_gfn     large     10
#                                          medium    10
#                                          small     10
# dtype: int64
#
# ================================================================================
# 找到 3 个 objectives: ['db_gfn', 'fl_db_gfn', 'tb_gfn']
# 找到 3 个 sizes: ['large', 'medium', 'small']
# 找到 3 个 reward_temps: [0.5, 1.0, 2.0]
# ================================================================================
#
# ================================================================================
# Objective: db_gfn, Size: large, Reward_temp: 0.5
# ================================================================================
#   实验数: 11
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 30065.2     3.781897e+10                  0.832246            0.989843
#    0.9 54528.0     2.468271e+11                  0.885260            0.971708
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 54528.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 246827082811.310699
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.885260
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.989843
#
# ================================================================================
# Objective: db_gfn, Size: large, Reward_temp: 1.0
# ================================================================================
#   实验数: 2
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.9  101.5    577246.860813                  0.882723            0.943095
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 101.500000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 577246.860813
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.882723
#   spearman_corr_test             -> 最优 alpha_init: 0.9000, 最优值: 0.943095
#
# ================================================================================
# Objective: db_gfn, Size: large, Reward_temp: 2.0
# ================================================================================
#   实验数: 7
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0       984.490217                  0.722196            0.961161
#    0.9   14.0    234979.098893                  0.867169            0.856356
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 14.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 234979.098893
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.867169
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.961161
#
# ================================================================================
# Objective: db_gfn, Size: medium, Reward_temp: 0.5
# ================================================================================
#   实验数: 8
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha    modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 102707.0     1.881284e+11                  0.783130            0.996407
#    0.9  62645.0     1.932809e+11                  0.820539            0.989589
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 102707.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 193280909588.144379
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.820539
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.996407
#
# ================================================================================
# Objective: db_gfn, Size: medium, Reward_temp: 1.0
# ================================================================================
#   实验数: 4
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0    112050.030668                  0.710606            0.990719
#    0.9   29.5    571243.481297                  0.807406            0.970514
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 29.500000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 571243.481297
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.807406
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.990719
#
# ================================================================================
# Objective: db_gfn, Size: medium, Reward_temp: 2.0
# ================================================================================
#   实验数: 8
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0      8730.553925                  0.665346            0.982753
#    0.9    7.0    316073.175589                  0.802901            0.935915
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 7.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 316073.175589
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.802901
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.982753
#
# ================================================================================
# Objective: db_gfn, Size: small, Reward_temp: 0.5
# ================================================================================
#   实验数: 9
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5  44.75         0.135065                  0.737653            0.998263
#    0.9  36.00         0.118217                  0.738341            0.997143
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 44.750000
#   mean_top_1000_R                -> 最优 alpha_init: 0.5000, 最优值: 0.135065
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.738341
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.998263
#
# ================================================================================
# Objective: db_gfn, Size: small, Reward_temp: 1.0
# ================================================================================
#   实验数: 4
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   26.0         0.184695                  0.694437            0.998776
#    0.9   35.0         0.195065                  0.708266            0.995213
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 35.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.195065
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.708266
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.998776
#
# ================================================================================
# Objective: db_gfn, Size: small, Reward_temp: 2.0
# ================================================================================
#   实验数: 7
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    6.0         0.132193                  0.646554            0.993986
#    0.9 1303.0         0.214521                  0.670071            0.987566
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 1303.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.214521
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.670071
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.993986
#
# ================================================================================
# Objective: fl_db_gfn, Size: large, Reward_temp: 0.5
# ================================================================================
#   实验数: 8
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 83618.0     3.799316e+11                  0.890225            0.790390
#    0.9 86940.5     3.836127e+11                  0.900762            0.712365
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 86940.500000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 383612700505.389099
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.900762
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.790390
#
# ================================================================================
# Objective: fl_db_gfn, Size: large, Reward_temp: 1.0
# ================================================================================
#   实验数: 3
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5  251.0    594597.205438                  0.852298            0.900143
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 251.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.5000, 最优值: 594597.205438
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.5000, 最优值: 0.852298
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.900143
#
# ================================================================================
# Objective: fl_db_gfn, Size: large, Reward_temp: 2.0
# ================================================================================
#   实验数: 9
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.6    151881.169802                  0.811220            0.886725
#    0.9   30.0    235449.298543                  0.851548            0.955844
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 30.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 235449.298543
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.851548
#   spearman_corr_test             -> 最优 alpha_init: 0.9000, 最优值: 0.955844
#
# ================================================================================
# Objective: fl_db_gfn, Size: medium, Reward_temp: 0.5
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 61654.0     2.321937e+11                  0.837076            0.885717
#    0.9 37305.4     1.528415e+11                  0.886148            0.754417
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 61654.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.5000, 最优值: 232193680345.399078
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.886148
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.885717
#
# ================================================================================
# Objective: fl_db_gfn, Size: medium, Reward_temp: 1.0
# ================================================================================
# 无数据，跳过
#
# ================================================================================
# Objective: fl_db_gfn, Size: medium, Reward_temp: 2.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.4    114602.213951                  0.752248            0.940074
#    0.9    0.4     89675.776735                  0.778303            0.987228
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 0.400000
#   mean_top_1000_R                -> 最优 alpha_init: 0.5000, 最优值: 114602.213951
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.778303
#   spearman_corr_test             -> 最优 alpha_init: 0.9000, 最优值: 0.987228
#
# ================================================================================
# Objective: fl_db_gfn, Size: small, Reward_temp: 0.5
# ================================================================================
#   实验数: 8
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   30.0         0.106761                  0.738379            0.940726
#    0.9   54.0         0.152573                  0.738282            0.829590
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 54.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.152573
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.5000, 最优值: 0.738379
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.940726
#
# ================================================================================
# Objective: fl_db_gfn, Size: small, Reward_temp: 1.0
# ================================================================================
#   实验数: 5
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha     modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 84.000000         0.218235                  0.734543            0.990989
#    0.9 88.333333         0.219762                  0.737081            0.974475
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 88.333333
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.219762
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.737081
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.990989
#
# ================================================================================
# Objective: fl_db_gfn, Size: small, Reward_temp: 2.0
# ================================================================================
#   实验数: 7
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 2862.2         0.236527                  0.706349            0.988523
#    0.9   62.0         0.208447                  0.728098            0.992024
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 2862.200000
#   mean_top_1000_R                -> 最优 alpha_init: 0.5000, 最优值: 0.236527
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.728098
#   spearman_corr_test             -> 最优 alpha_init: 0.9000, 最优值: 0.992024
#
# ================================================================================
# Objective: tb_gfn, Size: large, Reward_temp: 0.5
# ================================================================================
#   实验数: 11
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha        modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 23829.333333     4.544289e+09                  0.778547            0.991171
#    0.7 83011.625000     1.503440e+11                  0.838022            0.989416
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 83011.625000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 150344037268.833801
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.838022
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.991171
#
# ================================================================================
# Objective: tb_gfn, Size: large, Reward_temp: 1.0
# ================================================================================
#   实验数: 2
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0     11721.702002                  0.736479            0.996196
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 0.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.5000, 最优值: 11721.702002
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.5000, 最优值: 0.736479
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.996196
#
# ================================================================================
# Objective: tb_gfn, Size: large, Reward_temp: 2.0
# ================================================================================
#   实验数: 7
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0      1004.529811                  0.711737            0.997079
#    0.7    0.0    163281.819346                  0.871287            0.997197
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 0.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 163281.819346
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.871287
#   spearman_corr_test             -> 最优 alpha_init: 0.7000, 最优值: 0.997197
#
# ================================================================================
# Objective: tb_gfn, Size: medium, Reward_temp: 0.5
# ================================================================================
#   实验数: 11
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha        modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 54177.166667     4.030888e+10                  0.737149            0.996294
#    0.8 33499.400000     1.387610e+11                  0.854820            0.993434
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 54177.166667
#   mean_top_1000_R                -> 最优 alpha_init: 0.8000, 最优值: 138760995062.502441
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.8000, 最优值: 0.854820
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.996294
#
# ================================================================================
# Objective: tb_gfn, Size: medium, Reward_temp: 1.0
# ================================================================================
#   实验数: 5
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   0.00     46312.469949                  0.691674            0.997711
#    0.8 571.75    712400.577797                  0.852805            0.828058
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.8000, 最优值: 571.750000
#   mean_top_1000_R                -> 最优 alpha_init: 0.8000, 最优值: 712400.577797
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.8000, 最优值: 0.852805
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.997711
#
# ================================================================================
# Objective: tb_gfn, Size: medium, Reward_temp: 2.0
# ================================================================================
#   实验数: 4
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0      5216.960887                  0.660060            0.998300
#    0.8   49.0    614761.975491                  0.900263            0.985448
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.8000, 最优值: 49.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.8000, 最优值: 614761.975491
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.8000, 最优值: 0.900263
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.998300
#
# ================================================================================
# Objective: tb_gfn, Size: small, Reward_temp: 0.5
# ================================================================================
#   实验数: 6
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5  42.75         0.134036                  0.735993            0.999236
#    0.7  45.00         0.135431                  0.738350            0.998548
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 45.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 0.135431
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.738350
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.999236
#
# ================================================================================
# Objective: tb_gfn, Size: small, Reward_temp: 1.0
# ================================================================================
#   实验数: 4
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   21.0         0.179134                  0.688556            0.999383
#    0.7   27.0         0.184446                  0.694026            0.999217
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 27.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 0.184446
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.694026
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.999383
#
# ================================================================================
# Objective: tb_gfn, Size: small, Reward_temp: 2.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 1145.0         0.220976                  0.644618            0.999448
#    0.7  578.2         0.176359                  0.645244            0.999593
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 1145.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.5000, 最优值: 0.220976
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.645244
#   spearman_corr_test             -> 最优 alpha_init: 0.7000, 最优值: 0.999593
# source_file                   method     size    reward_temp
# rebuttal_set_temp_fixed.json  db_gfn     large   0.5            8
#                                                  2.0            2
#                                          medium  0.5            4
#                                                  2.0            6
#                                          small   0.5            4
#                                                  2.0            6
#                               fl_db_gfn  large   0.5            4
#                                                  2.0            6
#                                          medium  0.5            7
#                                                  2.0            3
#                                          small   0.5            4
#                                                  2.0            6
#                               tb_gfn     large   0.5            5
#                                                  2.0            5
#                                          medium  0.5            7
#                                                  2.0            3
#                                          small   0.5            3
#                                                  2.0            7
# rebuttal_set_temp_old.json    db_gfn     large   0.5            3
#                                                  1.0            2
#                                                  2.0            5
#                                          medium  0.5            4
#                                                  1.0            4
#                                                  2.0            2
#                                          small   0.5            5
#                                                  1.0            4
#                                                  2.0            1
#                               fl_db_gfn  large   0.5            4
#                                                  1.0            3
#                                                  2.0            3
#                                          medium  0.5            3
#                                                  2.0            7
#                                          small   0.5            4
#                                                  1.0            5
#                                                  2.0            1
#                               tb_gfn     large   0.5            6
#                                                  1.0            2
#                                                  2.0            2
#                                          medium  0.5            4
#                                                  1.0            5
#                                                  2.0            1
#                                          small   0.5            3
#                                                  1.0            4
#                                                  2.0            3
# dtype: int64

# %%
import matplotlib.pyplot as plt

out_dir = Path('side_product')
out_dir.mkdir(exist_ok=True, parents=True)

print(f"\n{'=' * 80}\n生成图表\n{'=' * 80}")
for cfg in fig_configs:
    obj = cfg['method']
    size = cfg['size']
    reward_temp = cfg['reward_temp']
    data = cfg['data']
    metrics_to_plot = cfg['metrics']

    n_metrics = len(metrics_to_plot)
    fig, axes = plt.subplots(1, n_metrics, figsize=(5*n_metrics, 4))
    if n_metrics == 1:
        axes = [axes]

    for idx, metric in enumerate(metrics_to_plot):
        ax = axes[idx]
        ax.plot(data['alpha'], data[metric], 'o-', linewidth=2, markersize=8)
        
        # 找到最优 alpha 并标注
        if len(data) > 0 and not data[metric].isna().all():
            # 排除 alpha=0.5，选择第二好的；否则选最优的
            sorted_data = data.sort_values(metric, ascending=False)
            candidates = sorted_data[sorted_data['alpha'] != 0.5]
            if len(candidates) > 0:
                best_idx = candidates.index[0]
            else:
                best_idx = data[metric].idxmax()
            
            best_alpha = data.loc[best_idx, 'alpha']
            best_value = data.loc[best_idx, metric]
            
            # 标注最优点（红星）
            ax.scatter([best_alpha], [best_value], color='red', s=200, zorder=5, marker='*', 
                      label=f'Best: α={best_alpha:.2f}')
            
            ax.set_xlabel('Alpha_init', fontsize=12)
            ax.set_ylabel(metric, fontsize=12)
            ax.set_title(f'{metric} vs Alpha_init', fontsize=12)
            ax.grid(True, alpha=0.3)
            ax.legend()

    plt.suptitle(f'Objective: {obj}, Size: {size}, Reward_temp: {reward_temp}', fontsize=14, fontweight='bold')
    plt.tight_layout()
    
    save_path = out_dir / f"set_analysis_{obj}_{size}_{reward_temp}.png"
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    print(f"✓ 已保存图表: {save_path}")
    plt.show()

print("\n" + "=" * 80)
print("✓ 所有图表生成完毕。")
print("=" * 80)

# %%
# 记录每个 cfg 对应的最优 alpha（用于筛选）
best_alpha_records = []

for cfg in fig_configs:
    obj = cfg['method']
    size = cfg['size']
    reward_temp = cfg['reward_temp']
    data = cfg['data']
    metrics_to_plot = cfg['metrics']
    
    for metric in metrics_to_plot:
        if len(data) > 0 and not data[metric].isna().all():
            # 使用相同的逻辑查找 best_alpha
            sorted_data = data.sort_values(metric, ascending=False)
            candidates = sorted_data[sorted_data['alpha'] != 0.5]
            if len(candidates) > 0:
                best_idx = candidates.index[0]
            else:
                best_idx = data[metric].idxmax()
            
            best_alpha = data.loc[best_idx, 'alpha']
            best_value = data.loc[best_idx, metric]
            
            best_alpha_records.append({
                'method': obj,
                'size': size,
                'reward_temp': reward_temp,
                'metric': metric,
                'best_alpha': best_alpha,
                'best_value': best_value
            })

# 转换为 DataFrame 并显示
df_best_alphas = pd.DataFrame(best_alpha_records)
print("\n" + "=" * 80)
print("最优 Alpha 汇总")
print("=" * 80)
print(df_best_alphas.to_string(index=False))

# 保存汇总表
best_alpha_csv_path = out_dir / 'best_alphas_summary.csv'
df_best_alphas.to_csv(best_alpha_csv_path, index=False)
print(f"\n✓ 已保存到: {best_alpha_csv_path}")

# 按照 best_alpha 筛选原始数据（保留所有 metric）
print("\n" + "=" * 80)
print("按照 best_alpha 筛选原始数据（保留所有指标）")
print("=" * 80)

best_alpha_data_records = []
# 获取每个 (method, size, reward_temp) 的唯一 best_alpha
for method in df_best_alphas['method'].unique():
    for size in df_best_alphas[df_best_alphas['method'] == method]['size'].unique():
        for reward_temp in df_best_alphas[(df_best_alphas['method'] == method) & (df_best_alphas['size'] == size)]['reward_temp'].unique():
            # 取该 (method, size, reward_temp) 的第一个 best_alpha
            best_alphas_for_msr = df_best_alphas[(df_best_alphas['method'] == method) & (df_best_alphas['size'] == size) & (df_best_alphas['reward_temp'] == reward_temp)]['best_alpha']
            if len(best_alphas_for_msr) > 0:
                best_alpha = best_alphas_for_msr.iloc[0]  # 取第一个
                
                # 从原始数据中筛选出该 method、size、reward_temp、alpha 的所有记录
                mask = (df_all['method'] == method) & (df_all['size'] == size) & (df_all['reward_temp'] == reward_temp) & (df_all['alpha'] == best_alpha)
                matched_rows = df_all[mask]
                
                if len(matched_rows) > 0:
                    # 计算平均和标准差
                    record = {
                        'method': method,
                        'size': size,
                        'reward_temp': reward_temp,
                        'alpha': best_alpha,
                    }
                    for m in metrics:
                        record[f'{m}_mean'] = matched_rows[m].mean()
                        record[f'{m}_std'] = matched_rows[m].std()
                    best_alpha_data_records.append(record)

df_best_alpha_data = pd.DataFrame(best_alpha_data_records)
print(df_best_alpha_data.to_string(index=False))

best_alpha_data_path = out_dir / 'best_alpha_data.csv'
df_best_alpha_data.to_csv(best_alpha_data_path, index=False)
print(f"\n✓ 已保存到: {best_alpha_data_path}")

# 保存 alpha_init=0.5 的 baseline 数据（包含均值和标准差）
print("\n" + "=" * 80)
print("Baseline 数据 (alpha_init=0.5) 的均值和标准差")
print("=" * 80)

baseline_records = []
for obj in objectives:
    for size in sizes:
        for reward_temp in reward_temps:
            df_obj = df_all[(df_all['method'] == obj) & (df_all['size'] == size) & (df_all['reward_temp'] == reward_temp) & (df_all['alpha'] == 0.5)].copy()
            if len(df_obj) > 0:
                record = {
                    'method': obj,
                    'size': size,
                    'reward_temp': reward_temp,
                    'alpha': 0.5,
                }
                for m in metrics:
                    record[f'{m}_mean'] = df_obj[m].mean()
                    record[f'{m}_std'] = df_obj[m].std()
                baseline_records.append(record)

df_baseline = pd.DataFrame(baseline_records)
if len(df_baseline) > 0:
    print(df_baseline.to_string(index=False))
    baseline_path = out_dir / 'baseline_alpha0.5_data.csv'
    df_baseline.to_csv(baseline_path, index=False)
    print(f"\n✓ 已保存到: {baseline_path}")
else:
    print("没有找到 alpha=0.5 的数据")
# Out:
# ================================================================================
# 最优 Alpha 汇总
# ================================================================================
#       method   size                   metric  best_alpha    best_value
#       db_gfn  large                    modes         0.9    355.800000
#       db_gfn  large          mean_top_1000_R         0.9 624721.771862
#       db_gfn  large mean_top_1000_similarity         0.9      0.882944
#       db_gfn  large       spearman_corr_test         0.9      0.944515
#       db_gfn medium                    modes         0.9     31.400000
#       db_gfn medium          mean_top_1000_R         0.9 552020.091131
#       db_gfn medium mean_top_1000_similarity         0.9      0.803490
#       db_gfn medium       spearman_corr_test         0.9      0.972678
#       db_gfn  small                    modes         0.9     55.800000
#       db_gfn  small          mean_top_1000_R         0.9      0.204380
#       db_gfn  small mean_top_1000_similarity         0.9      0.720881
#       db_gfn  small       spearman_corr_test         0.9      0.995274
#    fl_db_gfn  large                    modes         0.9   2239.200000
#    fl_db_gfn  large          mean_top_1000_R         0.9 768544.601063
#    fl_db_gfn  large mean_top_1000_similarity         0.9      0.874760
#    fl_db_gfn  large       spearman_corr_test         0.9      0.847180
#    fl_db_gfn medium                    modes         0.9    118.600000
#    fl_db_gfn medium          mean_top_1000_R         0.9 638688.096787
#    fl_db_gfn medium mean_top_1000_similarity         0.9      0.805760
#    fl_db_gfn medium       spearman_corr_test         0.9      0.934965
#    fl_db_gfn  small                    modes         0.9     88.600000
#    fl_db_gfn  small          mean_top_1000_R         0.9      0.219956
#    fl_db_gfn  small mean_top_1000_similarity         0.9      0.737103
#    fl_db_gfn  small       spearman_corr_test         0.9      0.974668
# fl_subtb_gfn  large                    modes         0.8   3809.400000
# fl_subtb_gfn  large          mean_top_1000_R         0.8 819447.403392
# fl_subtb_gfn  large mean_top_1000_similarity         0.9      0.896261
# fl_subtb_gfn  large       spearman_corr_test         0.7      0.972217
# fl_subtb_gfn medium                    modes         0.8    258.600000
# fl_subtb_gfn medium          mean_top_1000_R         0.8 655796.050813
# fl_subtb_gfn medium mean_top_1000_similarity         0.8      0.871578
# fl_subtb_gfn medium       spearman_corr_test         0.4      0.988201
# fl_subtb_gfn  small                    modes         0.6     90.000000
# fl_subtb_gfn  small          mean_top_1000_R         0.6      0.221347
# fl_subtb_gfn  small mean_top_1000_similarity         0.6      0.738192
# fl_subtb_gfn  small       spearman_corr_test         0.4      0.995710
#    subtb_gfn  large                    modes         0.8      2.000000
#    subtb_gfn  large          mean_top_1000_R         0.9 169377.546641
#    subtb_gfn  large mean_top_1000_similarity         0.9      0.903439
#    subtb_gfn  large       spearman_corr_test         0.1      0.929085
#    subtb_gfn medium                    modes         0.9      5.200000
#    subtb_gfn medium          mean_top_1000_R         0.9 434821.481532
#    subtb_gfn medium mean_top_1000_similarity         0.9      0.837826
#    subtb_gfn medium       spearman_corr_test         0.2      0.979274
#    subtb_gfn  small                    modes         0.8     34.200000
#    subtb_gfn  small          mean_top_1000_R         0.8      0.191337
#    subtb_gfn  small mean_top_1000_similarity         0.8      0.703432
#    subtb_gfn  small       spearman_corr_test         0.7      0.997132
#       tb_gfn  large                    modes         0.7    591.600000
#       tb_gfn  large          mean_top_1000_R         0.7 683702.459888
#       tb_gfn  large mean_top_1000_similarity         0.7      0.868523
#       tb_gfn  large       spearman_corr_test         0.7      0.996134
#       tb_gfn medium                    modes         0.8    499.000000
#       tb_gfn medium          mean_top_1000_R         0.8 703904.362100
#       tb_gfn medium mean_top_1000_similarity         0.8      0.857705
#       tb_gfn medium       spearman_corr_test         0.8      0.861677
#       tb_gfn  small                    modes         0.7     24.800000
#       tb_gfn  small          mean_top_1000_R         0.7      0.184035
#       tb_gfn  small mean_top_1000_similarity         0.7      0.693667
#       tb_gfn  small       spearman_corr_test         0.7      0.999332
#
# ✓ 已保存到: side_product\best_alphas_summary.csv
#
# ================================================================================
# 按照 best_alpha 筛选原始数据（保留所有指标）
# ================================================================================
#       method   size  alpha  modes_mean   modes_std  mean_top_1000_R_mean  mean_top_1000_R_std  mean_top_1000_similarity_mean  mean_top_1000_similarity_std  spearman_corr_test_mean  spearman_corr_test_std
#       db_gfn  large    0.9       355.8  319.840116         624721.771862         55336.884563                       0.882944                      0.006609                 0.944515                0.004377
#       db_gfn medium    0.9        31.4   34.063177         552020.091131         59210.234237                       0.803490                      0.009403                 0.972678                0.005112
#       db_gfn  small    0.9        55.8   13.917615              0.204380             0.006146                       0.720881                      0.007723                 0.995274                0.000519
#    fl_db_gfn  large    0.9      2239.2  169.798999         768544.601063          6904.368877                       0.874760                      0.001656                 0.847180                0.017983
#    fl_db_gfn medium    0.9       118.6   45.878099         638688.096787         24711.413502                       0.805760                      0.005749                 0.934965                0.012631
#    fl_db_gfn  small    0.9        88.6    2.190890              0.219956             0.002011                       0.737103                      0.001380                 0.974668                0.006591
# fl_subtb_gfn  large    0.8      3809.4 1893.070469         819447.403392         61927.154859                       0.886286                      0.010556                 0.968787                0.004371
# fl_subtb_gfn medium    0.8       258.6  296.321278         655796.050813         68334.689598                       0.871578                      0.008508                 0.775404                0.031217
# fl_subtb_gfn  small    0.6        90.0    0.000000              0.221347             0.000067                       0.738192                      0.000097                 0.990751                0.002419
#    subtb_gfn  large    0.8         2.0    4.472136         159144.732609         87726.562438                       0.872159                      0.016763                 0.916322                0.016924
#    subtb_gfn medium    0.9         5.2    6.760178         434821.481532         78120.946700                       0.837826                      0.009911                 0.955813                0.013034
#    subtb_gfn  small    0.8        34.2    8.074652              0.191337             0.005553                       0.703432                      0.007601                 0.996759                0.000989
#       tb_gfn  large    0.7       591.6  210.561867         683702.459888         32706.822281                       0.868523                      0.006927                 0.996134                0.000757
#       tb_gfn medium    0.8       499.0  427.071423         703904.362100         39194.702865                       0.857705                      0.011781                 0.861677                0.300486
#       tb_gfn  small    0.7        24.8    3.271085              0.184035             0.001664                       0.693667                      0.001708                 0.999332                0.000388
#
# ✓ 已保存到: side_product\best_alpha_data.csv
#
# ================================================================================
# Baseline 数据 (alpha_init=0.5) 的均值和标准差
# ================================================================================
#       method   size  alpha  modes_mean  modes_std  mean_top_1000_R_mean  mean_top_1000_R_std  mean_top_1000_similarity_mean  mean_top_1000_similarity_std  spearman_corr_test_mean  spearman_corr_test_std
#       db_gfn  large    0.5         0.0   0.000000          58086.535407          5216.945176                       0.763214                      0.001974                 0.984226                0.003840
#       db_gfn medium    0.5         0.0   0.000000         110427.380192          5337.251186                       0.710264                      0.001300                 0.992868                0.004152
#       db_gfn  small    0.5        24.8   2.588436              0.184467             0.001219                       0.694183                      0.001272                 0.998606                0.000361
#    fl_db_gfn  large    0.5       247.6 147.167592         593090.240612         67865.241768                       0.852669                      0.007942                 0.902304                0.019388
#    fl_db_gfn medium    0.5        14.2  10.059821         507462.734981         47471.449511                       0.782299                      0.005843                 0.967982                0.007727
#    fl_db_gfn  small    0.5        83.0   2.449490              0.218038             0.000583                       0.734215                      0.000717                 0.991999                0.002448
# fl_subtb_gfn  large    0.5       190.2  48.664155         589971.983094         25231.393620                       0.850742                      0.002893                 0.973308                0.007063
# fl_subtb_gfn medium    0.5        16.0   8.602325         531806.165717         14738.447098                       0.784460                      0.002265                 0.972305                0.005822
# fl_subtb_gfn  small    0.5        89.6   0.894427              0.221153             0.000268                       0.737923                      0.000341                 0.996585                0.000948
#    subtb_gfn  large    0.5         0.0   0.000000          53579.355185         27673.865227                       0.790354                      0.017526                 0.943681                0.008026
#    subtb_gfn medium    0.5         0.0   0.000000         160688.926543         40230.654574                       0.732542                      0.008181                 0.967823                0.006930
#    subtb_gfn  small    0.5        20.0   4.062019              0.178573             0.001908                       0.687857                      0.001890                 0.991776                0.004937
#       tb_gfn  large    0.5         0.0   0.000000          11754.280200           230.908734                       0.736443                      0.000322                 0.995855                0.000449
#       tb_gfn medium    0.5         0.0   0.000000          44854.405848          1480.967046                       0.691062                      0.000837                 0.997923                0.000459
#       tb_gfn  small    0.5        23.2   2.387467              0.179905             0.001319                       0.689238                      0.001323                 0.999477                0.000179
#
# ✓ 已保存到: side_product\baseline_alpha0.5_data.csv

# %%
# 合并 best_alpha_data 和 baseline_data
print("\n" + "=" * 80)
print("合并最优 Alpha 和 Baseline 数据")
print("=" * 80)

df_combined = pd.concat([df_best_alpha_data, df_baseline], ignore_index=True)

# 按照 method、size、alpha 排序
df_combined = df_combined.sort_values(['method', 'size', 'alpha']).reset_index(drop=True)

print(df_combined.to_string(index=False))
import os
os.makedirs('results', exist_ok=True)

combined_path = Path('results') / 'data.csv'
df_combined.to_csv(combined_path, index=False)
print(f"\n✓ 已保存到: {combined_path}")
# Out:
# ================================================================================
# 合并最优 Alpha 和 Baseline 数据
# ================================================================================
#       method   size  alpha  modes_mean   modes_std  mean_top_1000_R_mean  mean_top_1000_R_std  mean_top_1000_similarity_mean  mean_top_1000_similarity_std  spearman_corr_test_mean  spearman_corr_test_std
#       db_gfn  large    0.5         0.0    0.000000          58086.535407          5216.945176                       0.763214                      0.001974                 0.984226                0.003840
#       db_gfn  large    0.9       355.8  319.840116         624721.771862         55336.884563                       0.882944                      0.006609                 0.944515                0.004377
#       db_gfn medium    0.5         0.0    0.000000         110427.380192          5337.251186                       0.710264                      0.001300                 0.992868                0.004152
#       db_gfn medium    0.9        31.4   34.063177         552020.091131         59210.234237                       0.803490                      0.009403                 0.972678                0.005112
#       db_gfn  small    0.5        24.8    2.588436              0.184467             0.001219                       0.694183                      0.001272                 0.998606                0.000361
#       db_gfn  small    0.9        55.8   13.917615              0.204380             0.006146                       0.720881                      0.007723                 0.995274                0.000519
#    fl_db_gfn  large    0.5       247.6  147.167592         593090.240612         67865.241768                       0.852669                      0.007942                 0.902304                0.019388
#    fl_db_gfn  large    0.9      2239.2  169.798999         768544.601063          6904.368877                       0.874760                      0.001656                 0.847180                0.017983
#    fl_db_gfn medium    0.5        14.2   10.059821         507462.734981         47471.449511                       0.782299                      0.005843                 0.967982                0.007727
#    fl_db_gfn medium    0.9       118.6   45.878099         638688.096787         24711.413502                       0.805760                      0.005749                 0.934965                0.012631
#    fl_db_gfn  small    0.5        83.0    2.449490              0.218038             0.000583                       0.734215                      0.000717                 0.991999                0.002448
#    fl_db_gfn  small    0.9        88.6    2.190890              0.219956             0.002011                       0.737103                      0.001380                 0.974668                0.006591
# fl_subtb_gfn  large    0.5       190.2   48.664155         589971.983094         25231.393620                       0.850742                      0.002893                 0.973308                0.007063
# fl_subtb_gfn  large    0.8      3809.4 1893.070469         819447.403392         61927.154859                       0.886286                      0.010556                 0.968787                0.004371
# fl_subtb_gfn medium    0.5        16.0    8.602325         531806.165717         14738.447098                       0.784460                      0.002265                 0.972305                0.005822
# fl_subtb_gfn medium    0.8       258.6  296.321278         655796.050813         68334.689598                       0.871578                      0.008508                 0.775404                0.031217
# fl_subtb_gfn  small    0.5        89.6    0.894427              0.221153             0.000268                       0.737923                      0.000341                 0.996585                0.000948
# fl_subtb_gfn  small    0.6        90.0    0.000000              0.221347             0.000067                       0.738192                      0.000097                 0.990751                0.002419
#    subtb_gfn  large    0.5         0.0    0.000000          53579.355185         27673.865227                       0.790354                      0.017526                 0.943681                0.008026
#    subtb_gfn  large    0.8         2.0    4.472136         159144.732609         87726.562438                       0.872159                      0.016763                 0.916322                0.016924
#    subtb_gfn medium    0.5         0.0    0.000000         160688.926543         40230.654574                       0.732542                      0.008181                 0.967823                0.006930
#    subtb_gfn medium    0.9         5.2    6.760178         434821.481532         78120.946700                       0.837826                      0.009911                 0.955813                0.013034
#    subtb_gfn  small    0.5        20.0    4.062019              0.178573             0.001908                       0.687857                      0.001890                 0.991776                0.004937
#    subtb_gfn  small    0.8        34.2    8.074652              0.191337             0.005553                       0.703432                      0.007601                 0.996759                0.000989
#       tb_gfn  large    0.5         0.0    0.000000          11754.280200           230.908734                       0.736443                      0.000322                 0.995855                0.000449
#       tb_gfn  large    0.7       591.6  210.561867         683702.459888         32706.822281                       0.868523                      0.006927                 0.996134                0.000757
#       tb_gfn medium    0.5         0.0    0.000000          44854.405848          1480.967046                       0.691062                      0.000837                 0.997923                0.000459
#       tb_gfn medium    0.8       499.0  427.071423         703904.362100         39194.702865                       0.857705                      0.011781                 0.861677                0.300486
#       tb_gfn  small    0.5        23.2    2.387467              0.179905             0.001319                       0.689238                      0.001323                 0.999477                0.000179
#       tb_gfn  small    0.7        24.8    3.271085              0.184035             0.001664                       0.693667                      0.001708                 0.999332                0.000388
#
# ✓ 已保存到: results\data.csv
