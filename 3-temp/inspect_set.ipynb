# %%
import json
import pandas as pd
from pathlib import Path
from typing import Dict, Any

# 指定目录和 json 文件
data_dir = Path('.')
json_files = [
    'rebuttal_set_temp_old.json',
    'rebuttal_set_temp_fixed.json'
]

def flatten_dict(d: Dict[str, Any], parent_key: str = '', sep: str = '_') -> Dict[str, Any]:
    """递归展平嵌套字典"""
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# 加载所有 json 文件并解析为 DataFrame
all_data = []

for file in json_files:
    file_path = data_dir / file
    with open(file_path, 'r') as f:
        data = json.load(f)

    # 每个 json 文件的顶层 key 是实验名称，value 是参数字典
    for exp_name, exp_params in data.items():
        flat_params = flatten_dict(exp_params)
        flat_params['experiment_name'] = exp_name  # 保存实验名称
        flat_params['source_file'] = file  # 保存来源文件
        all_data.append(flat_params)

# 转换为 DataFrame
df = pd.DataFrame(all_data)

print(f"✓ 加载完成！共 {len(df)} 行")
print(f"✓ 列数: {len(df.columns)}")
print(f"\n数据源: {json_files}")
print(f"\nDataFrame 形状: {df.shape}")
print(f"\n前几行:")
df.head()
# Out:
# ✓ 加载完成！共 450 行
# ✓ 列数: 112
#
# 数据源: ['rebuttal_set_temp_old.json', 'rebuttal_set_temp_fixed.json']
#
# DataFrame 形状: (450, 112)
#
# 前几行:
#       _runtime  _step    _timestamp  action_dim     alpha  alpha_init  \
# 0  2188.286372    200  1.763515e+09          30  0.503678         0.7
# 1  2408.449633    200  1.763525e+09          30  0.507356         0.9
# 2  4464.348825    200  1.763507e+09          80  0.500000         0.5
# 3  3656.951993    200  1.763525e+09          80  0.507356         0.9
# 4  5519.194801    200  1.763526e+09          80  0.507356         0.9
#
#    alpha_logit  alpha_lr alpha_sched  alpha_train_first_steps  ...  \
# 0     0.014711     0.001    hold_exp                    False  ...
# 1     0.029425     0.001    hold_exp                    False  ...
# 2     0.000000     0.001    hold_exp                    False  ...
# 3     0.029425     0.001    hold_exp                    False  ...
# 4     0.029425     0.001    hold_exp                    False  ...
#
#    use_alpha_scheduler use_exp_weight_decay  use_external_sampling_model  \
# 0                 True                    1                        False
# 1                 True                    1                        False
# 2                 True                    1                        False
# 3                 True                    1                        False
# 4                 True                    1                        False
#
#    use_grad_clip  use_modified_reward  use_replay_buffer   wdb  \
# 0          False                False              False  True
# 1          False                False              False  True
# 2          False                False              False  True
# 3          False                False              False  True
# 4          False                False              False  True
#
#            wdb_group                                    experiment_name  \
# 0  set_temp_rebuttal  ss(2)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(small)_m(...
# 1  set_temp_rebuttal  ss(2)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(small)_m(...
# 2  set_temp_rebuttal  ss(1)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(medium)_m...
# 3  set_temp_rebuttal  ss(1)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(medium)_m...
# 4  set_temp_rebuttal  ss(2)_ms(0)_md(on)_mdfr(0)_upb(1)_sz(medium)_m...
#
#                   source_file
# 0  rebuttal_set_temp_old.json
# 1  rebuttal_set_temp_old.json
# 2  rebuttal_set_temp_old.json
# 3  rebuttal_set_temp_old.json
# 4  rebuttal_set_temp_old.json
#
# [5 rows x 112 columns]

# %%
import re
import numpy as np

# 复制一份以免污染原始 df
df_all = df.copy()

# 解析实验名称中的参数
def parse_exp_name(exp_name: str) -> dict:
    params = {}
    ss_match = re.search(r'ss\((\d+)\)', exp_name)
    if ss_match:
        params['seed'] = int(ss_match.group(1))

    m_match = re.search(r'_m\(([^)]+)\)', exp_name)
    if m_match:
        params['method'] = m_match.group(1)

    # 提取size sz(xxx)
    sz_match = re.search(r'_sz\(([^)]+)\)', exp_name)
    if sz_match:
        params['size'] = sz_match.group(1)

    a_match = re.search(r'_a\(([^)]+)\)', exp_name)
    if a_match:
        try:
            params['alpha_init_from_name'] = float(a_match.group(1))
        except ValueError:
            params['alpha_init_from_name'] = np.nan

    return params

parsed_rows = []
for _, row in df_all.iterrows():
    name = row.get('experiment_name', '')
    parsed = parse_exp_name(name)
    method = parsed.get('method')
    
    # 来自这个文件的method加上"fl-"前缀
    source_file = row.get('source_file', '')
    if source_file in ['refactored_alpha_gfn_set_new_icml.json']:
        if method:
            method = f"fl_{method}"
    
    parsed_rows.append({
        **row,
        'seed': parsed.get('seed'),
        'method': method,
        'size': parsed.get('size'),
        'alpha_init_name': parsed.get('alpha_init_from_name'),
        'alpha': row.get('alpha_init', row.get('alpha'))
    })

df_all = pd.DataFrame(parsed_rows)

# 过滤掉来自 rebuttal_set_fl.json 且 method 为 subtb_gfn 的数据
before_filter = len(df_all)
df_all = df_all[~((df_all['source_file'] == 'rebuttal_set_fl.json') & (df_all['method'] == 'subtb_gfn'))]
after_filter = len(df_all)
if before_filter > after_filter:
    print(f"✓ 已过滤掉 {before_filter - after_filter} 条数据（来自 rebuttal_set_fl.json 且 method=subtb_gfn）\n")

print(f"总实验数: {len(df_all)}")
print(f"Unique seeds: {sorted(df_all['seed'].dropna().unique())}")
print(f"Unique sizes: {sorted(df_all['size'].dropna().unique())}")
print(f"Unique alphas (from alpha_init): {sorted(df_all['alpha'].dropna().unique())}")
print(f"Unique objectives/methods: {sorted(df_all['method'].dropna().unique())}")
print(f"Unique reward_temp labels: {sorted(df_all['reward_temp'].dropna().unique())}")
print("\n数据来源分布:")
print(df_all.groupby(['source_file', 'method', 'size']).size())

# 使用指定的评估指标
metrics = ['modes', 'mean_top_1000_R', 'mean_top_1000_similarity', 'spearman_corr_test']

# 检查哪些指标存在
available_metrics = [m for m in metrics if m in df_all.columns]
missing_metrics = [m for m in metrics if m not in df_all.columns]

if missing_metrics:
    print(f"⚠️ 缺失指标: {missing_metrics}")
    print(f"✓ 可用指标: {available_metrics}\n")
    metrics = available_metrics

objectives = sorted(df_all['method'].dropna().unique())
sizes = sorted(df_all['size'].dropna().unique())
reward_temps = sorted(df_all['reward_temp'].dropna().unique())

print(f"\n{'=' * 80}")
print(f"找到 {len(objectives)} 个 objectives: {objectives}")
print(f"找到 {len(sizes)} 个 sizes: {sizes}")
print(f"找到 {len(reward_temps)} 个 reward_temps: {reward_temps}")
print(f"{'=' * 80}")

# 收集绘图配置
fig_configs = []

for obj in objectives:
    for size in sizes:
        for reward_temp in reward_temps:
            print(f"\n{'=' * 80}")
            print(f"Objective: {obj}, Size: {size}, Reward_temp: {reward_temp}")
            print(f"{'=' * 80}")

            df_obj = df_all[(df_all['method'] == obj) & (df_all['size'] == size) & (df_all['reward_temp'] == reward_temp)].copy()
            if len(df_obj) == 0:
                print("无数据，跳过")
                continue

            print(f"  实验数: {len(df_obj)}")
            print(f"  来源文件: {df_obj['source_file'].unique()}")

            df_averaged = df_obj.groupby('alpha')[metrics].mean().reset_index()
            df_averaged = df_averaged.sort_values('alpha')

            print("\n按 seed 平均后的结果 (基于 alpha_init):")
            print(df_averaged.to_string(index=False))

            print("\n最优 Alpha 分析:")
            print(f"{'-' * 80}")
            for metric in metrics:
                if len(df_averaged) > 0 and not df_averaged[metric].isna().all():
                    best_idx = df_averaged[metric].idxmax()
                    best_alpha = df_averaged.loc[best_idx, 'alpha']
                    best_value = df_averaged.loc[best_idx, metric]
                    print(f"  {metric:30s} -> 最优 alpha_init: {best_alpha:.4f}, 最优值: {best_value:.6f}")

            plot_metrics = [m for m in metrics if not df_averaged[m].isna().all()]
            if plot_metrics:
                fig_configs.append({
                    'method': obj,
                    'size': size,
                    'reward_temp': reward_temp,
                    'data': df_averaged,
                    'metrics': plot_metrics
                })
print(df_all.groupby(['source_file', 'method', 'size', 'reward_temp']).size())
# Out:
# 总实验数: 450
# Unique seeds: [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4)]
# Unique sizes: ['large', 'medium', 'small']
# Unique alphas (from alpha_init): [np.float64(0.5), np.float64(0.7), np.float64(0.8), np.float64(0.9)]
# Unique objectives/methods: ['db_gfn', 'fl_db_gfn', 'tb_gfn']
# Unique reward_temp labels: [np.float64(0.5), np.float64(1.0), np.float64(2.0)]
#
# 数据来源分布:
# source_file                   method     size
# rebuttal_set_temp_fixed.json  db_gfn     large     20
#                                          medium    20
#                                          small     20
#                               fl_db_gfn  large     20
#                                          medium    20
#                                          small     20
#                               tb_gfn     large     20
#                                          medium    20
#                                          small     20
# rebuttal_set_temp_old.json    db_gfn     large     30
#                                          medium    30
#                                          small     30
#                               fl_db_gfn  large     30
#                                          medium    30
#                                          small     30
#                               tb_gfn     large     30
#                                          medium    30
#                                          small     30
# dtype: int64
#
# ================================================================================
# 找到 3 个 objectives: ['db_gfn', 'fl_db_gfn', 'tb_gfn']
# 找到 3 个 sizes: ['large', 'medium', 'small']
# 找到 3 个 reward_temps: [np.float64(0.5), np.float64(1.0), np.float64(2.0)]
# ================================================================================
#
# ================================================================================
# Objective: db_gfn, Size: large, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 74813.7     9.964607e+10                  0.832313            0.990223
#    0.9 78631.3     3.774861e+11                  0.887085            0.974907
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 78631.300000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 377486090586.405090
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.887085
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.990223
#
# ================================================================================
# Objective: db_gfn, Size: large, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0     58086.535407                  0.763214            0.984226
#    0.9  355.8    624721.771862                  0.882944            0.944515
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 355.800000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 624721.771862
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.882944
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.984226
#
# ================================================================================
# Objective: db_gfn, Size: large, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0      2214.608954                  0.721983            0.962783
#    0.9   37.7    224447.863829                  0.858223            0.837054
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 37.700000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 224447.863829
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.858223
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.962783
#
# ================================================================================
# Objective: db_gfn, Size: medium, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 77080.8     1.419974e+11                  0.782948            0.995319
#    0.9 78223.1     2.499582e+11                  0.820503            0.988906
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 78223.100000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 249958214217.933777
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.820503
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.995319
#
# ================================================================================
# Objective: db_gfn, Size: medium, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0    110427.380192                  0.710264            0.992868
#    0.9   31.4    552020.091131                  0.803490            0.972678
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 31.400000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 552020.091131
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.803490
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.992868
#
# ================================================================================
# Objective: db_gfn, Size: medium, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0      5482.109415                  0.665284            0.982484
#    0.9    3.0    234701.118758                  0.800167            0.931081
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 3.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 234701.118758
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.800167
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.982484
#
# ================================================================================
# Objective: db_gfn, Size: small, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   44.8         0.135062                  0.737626            0.998591
#    0.9   45.0         0.135410                  0.738323            0.996865
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 45.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.135410
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.738323
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.998591
#
# ================================================================================
# Objective: db_gfn, Size: small, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   24.8         0.184467                  0.694183            0.998606
#    0.9   55.8         0.204380                  0.720881            0.995274
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 55.800000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.204380
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.720881
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.998606
#
# ================================================================================
# Objective: db_gfn, Size: small, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 1523.5         0.247500                  0.647043            0.992799
#    0.9 2335.1         0.275003                  0.672250            0.986035
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 2335.100000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.275003
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.672250
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.992799
#
# ================================================================================
# Objective: fl_db_gfn, Size: large, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 84088.5     3.828032e+11                  0.891765            0.796938
#    0.9 86386.7     3.835655e+11                  0.900365            0.716344
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 86386.700000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 383565516710.827698
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.900365
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.796938
#
# ================================================================================
# Objective: fl_db_gfn, Size: large, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5  247.6    593090.240612                  0.852669            0.902304
#    0.9 2239.2    768544.601063                  0.874760            0.847180
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 2239.200000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 768544.601063
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.874760
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.902304
#
# ================================================================================
# Objective: fl_db_gfn, Size: large, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.4     88839.952295                  0.808503            0.897579
#    0.9   28.7    236387.393644                  0.850055            0.948744
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 28.700000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 236387.393644
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.850055
#   spearman_corr_test             -> 最优 alpha_init: 0.9000, 最优值: 0.948744
#
# ================================================================================
# Objective: fl_db_gfn, Size: medium, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 76712.5     2.891030e+11                  0.836134            0.884396
#    0.9 82336.8     3.810110e+11                  0.887122            0.747115
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 82336.800000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 381011017816.702209
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.887122
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.884396
#
# ================================================================================
# Objective: fl_db_gfn, Size: medium, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   14.2    507462.734981                  0.782299            0.967982
#    0.9  118.6    638688.096787                  0.805760            0.934965
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 118.600000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 638688.096787
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.805760
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.967982
#
# ================================================================================
# Objective: fl_db_gfn, Size: medium, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.2    127342.621577                  0.747961            0.946308
#    0.9    2.2    229547.403728                  0.779097            0.987645
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 2.200000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 229547.403728
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.779097
#   spearman_corr_test             -> 最优 alpha_init: 0.9000, 最优值: 0.987645
#
# ================================================================================
# Objective: fl_db_gfn, Size: small, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   45.0         0.135436                  0.738377            0.935839
#    0.9   45.0         0.135385                  0.738279            0.836364
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.5000, 最优值: 45.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.5000, 最优值: 0.135436
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.5000, 最优值: 0.738377
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.935839
#
# ================================================================================
# Objective: fl_db_gfn, Size: small, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   83.0         0.218038                  0.734215            0.991999
#    0.9   88.6         0.219956                  0.737103            0.974668
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 88.600000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.219956
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.737103
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.991999
#
# ================================================================================
# Objective: fl_db_gfn, Size: small, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 5874.6         0.308382                  0.706938            0.987478
#    0.9 9628.9         0.336859                  0.732110            0.990508
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.9000, 最优值: 9628.900000
#   mean_top_1000_R                -> 最优 alpha_init: 0.9000, 最优值: 0.336859
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.9000, 最优值: 0.732110
#   spearman_corr_test             -> 最优 alpha_init: 0.9000, 最优值: 0.990508
#
# ================================================================================
# Objective: tb_gfn, Size: large, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 35760.3     6.412997e+09                   0.77857            0.990589
#    0.7 66419.7     1.202753e+11                   0.83790            0.989635
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 66419.700000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 120275325147.569168
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.837900
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.990589
#
# ================================================================================
# Objective: tb_gfn, Size: large, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0     11754.280200                  0.736443            0.995855
#    0.7  591.6    683702.459888                  0.868523            0.996134
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 591.600000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 683702.459888
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.868523
#   spearman_corr_test             -> 最优 alpha_init: 0.7000, 最优值: 0.996134
#
# ================================================================================
# Objective: tb_gfn, Size: large, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0       850.399089                  0.711691            0.997108
#    0.7    0.2     95883.130738                  0.877960            0.997571
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 0.200000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 95883.130738
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.877960
#   spearman_corr_test             -> 最优 alpha_init: 0.7000, 最优值: 0.997571
#
# ================================================================================
# Objective: tb_gfn, Size: medium, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha   modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 54155.4     3.989278e+10                  0.737038            0.996285
#    0.8 78838.6     3.430234e+11                  0.857029            0.993735
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.8000, 最优值: 78838.600000
#   mean_top_1000_R                -> 最优 alpha_init: 0.8000, 最优值: 343023376415.779419
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.8000, 最优值: 0.857029
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.996285
#
# ================================================================================
# Objective: tb_gfn, Size: medium, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0     44854.405848                  0.691062            0.997923
#    0.8  499.0    703904.362100                  0.857705            0.861677
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.8000, 最优值: 499.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.8000, 最优值: 703904.362100
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.8000, 最优值: 0.857705
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.997923
#
# ================================================================================
# Objective: tb_gfn, Size: medium, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5    0.0      3964.936445                  0.660433            0.998343
#    0.8    8.0    238482.283050                  0.877343            0.987535
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.8000, 最优值: 8.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.8000, 最优值: 238482.283050
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.8000, 最优值: 0.877343
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.998343
#
# ================================================================================
# Objective: tb_gfn, Size: small, Reward_temp: 0.5
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   43.3         0.134066                  0.735912            0.999275
#    0.7   45.0         0.135429                  0.738350            0.998903
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 45.000000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 0.135429
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.738350
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.999275
#
# ================================================================================
# Objective: tb_gfn, Size: small, Reward_temp: 1.0
# ================================================================================
#   实验数: 10
#   来源文件: ['rebuttal_set_temp_old.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5   23.2         0.179905                  0.689238            0.999477
#    0.7   24.8         0.184035                  0.693667            0.999332
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 24.800000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 0.184035
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.693667
#   spearman_corr_test             -> 最优 alpha_init: 0.5000, 最优值: 0.999477
#
# ================================================================================
# Objective: tb_gfn, Size: small, Reward_temp: 2.0
# ================================================================================
#   实验数: 20
#   来源文件: ['rebuttal_set_temp_old.json' 'rebuttal_set_temp_fixed.json']
#
# 按 seed 平均后的结果 (基于 alpha_init):
#  alpha  modes  mean_top_1000_R  mean_top_1000_similarity  spearman_corr_test
#    0.5 1428.3         0.244791                  0.645166            0.999441
#    0.7 1460.5         0.245756                  0.645817            0.999447
#
# 最优 Alpha 分析:
# --------------------------------------------------------------------------------
#   modes                          -> 最优 alpha_init: 0.7000, 最优值: 1460.500000
#   mean_top_1000_R                -> 最优 alpha_init: 0.7000, 最优值: 0.245756
#   mean_top_1000_similarity       -> 最优 alpha_init: 0.7000, 最优值: 0.645817
#   spearman_corr_test             -> 最优 alpha_init: 0.7000, 最优值: 0.999447
# source_file                   method     size    reward_temp
# rebuttal_set_temp_fixed.json  db_gfn     large   0.5            10
#                                                  2.0            10
#                                          medium  0.5            10
#                                                  2.0            10
#                                          small   0.5            10
#                                                  2.0            10
#                               fl_db_gfn  large   0.5            10
#                                                  2.0            10
#                                          medium  0.5            10
#                                                  2.0            10
#                                          small   0.5            10
#                                                  2.0            10
#                               tb_gfn     large   0.5            10
#                                                  2.0            10
#                                          medium  0.5            10
#                                                  2.0            10
#                                          small   0.5            10
#                                                  2.0            10
# rebuttal_set_temp_old.json    db_gfn     large   0.5            10
#                                                  1.0            10
#                                                  2.0            10
#                                          medium  0.5            10
#                                                  1.0            10
#                                                  2.0            10
#                                          small   0.5            10
#                                                  1.0            10
#                                                  2.0            10
#                               fl_db_gfn  large   0.5            10
#                                                  1.0            10
#                                                  2.0            10
#                                          medium  0.5            10
#                                                  1.0            10
#                                                  2.0            10
#                                          small   0.5            10
#                                                  1.0            10
#                                                  2.0            10
#                               tb_gfn     large   0.5            10
#                                                  1.0            10
#                                                  2.0            10
#                                          medium  0.5            10
#                                                  1.0            10
#                                                  2.0            10
#                                          small   0.5            10
#                                                  1.0            10
#                                                  2.0            10
# dtype: int64

# %%
import matplotlib.pyplot as plt

out_dir = Path('side_product')
out_dir.mkdir(exist_ok=True, parents=True)

print(f"\n{'=' * 80}\n生成图表\n{'=' * 80}")
for cfg in fig_configs:
    obj = cfg['method']
    size = cfg['size']
    reward_temp = cfg['reward_temp']
    data = cfg['data']
    metrics_to_plot = cfg['metrics']

    n_metrics = len(metrics_to_plot)
    fig, axes = plt.subplots(1, n_metrics, figsize=(5*n_metrics, 4))
    if n_metrics == 1:
        axes = [axes]

    for idx, metric in enumerate(metrics_to_plot):
        ax = axes[idx]
        ax.plot(data['alpha'], data[metric], 'o-', linewidth=2, markersize=8)
        
        # 找到最优 alpha 并标注
        if len(data) > 0 and not data[metric].isna().all():
            # 排除 alpha=0.5，选择第二好的；否则选最优的
            sorted_data = data.sort_values(metric, ascending=False)
            candidates = sorted_data[sorted_data['alpha'] != 0.5]
            if len(candidates) > 0:
                best_idx = candidates.index[0]
            else:
                best_idx = data[metric].idxmax()
            
            best_alpha = data.loc[best_idx, 'alpha']
            best_value = data.loc[best_idx, metric]
            
            # 标注最优点（红星）
            ax.scatter([best_alpha], [best_value], color='red', s=200, zorder=5, marker='*', 
                      label=f'Best: α={best_alpha:.2f}')
            
            ax.set_xlabel('Alpha_init', fontsize=12)
            ax.set_ylabel(metric, fontsize=12)
            ax.set_title(f'{metric} vs Alpha_init', fontsize=12)
            ax.grid(True, alpha=0.3)
            ax.legend()

    plt.suptitle(f'Objective: {obj}, Size: {size}, Reward_temp: {reward_temp}', fontsize=14, fontweight='bold')
    plt.tight_layout()
    
    save_path = out_dir / f"set_analysis_{obj}_{size}_{reward_temp}.png"
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    print(f"✓ 已保存图表: {save_path}")
    plt.show()

print("\n" + "=" * 80)
print("✓ 所有图表生成完毕。")
print("=" * 80)

# %%
# 记录每个 cfg 对应的最优 alpha（用于筛选）
best_alpha_records = []

for cfg in fig_configs:
    obj = cfg['method']
    size = cfg['size']
    reward_temp = cfg['reward_temp']
    data = cfg['data']
    metrics_to_plot = cfg['metrics']
    
    for metric in metrics_to_plot:
        if len(data) > 0 and not data[metric].isna().all():
            # 使用相同的逻辑查找 best_alpha
            sorted_data = data.sort_values(metric, ascending=False)
            candidates = sorted_data[sorted_data['alpha'] != 0.5]
            if len(candidates) > 0:
                best_idx = candidates.index[0]
            else:
                best_idx = data[metric].idxmax()
            
            best_alpha = data.loc[best_idx, 'alpha']
            best_value = data.loc[best_idx, metric]
            
            best_alpha_records.append({
                'method': obj,
                'size': size,
                'reward_temp': reward_temp,
                'metric': metric,
                'best_alpha': best_alpha,
                'best_value': best_value
            })

# 转换为 DataFrame 并显示
df_best_alphas = pd.DataFrame(best_alpha_records)
print("\n" + "=" * 80)
print("最优 Alpha 汇总")
print("=" * 80)
print(df_best_alphas.to_string(index=False))

# 保存汇总表
best_alpha_csv_path = out_dir / 'best_alphas_summary.csv'
df_best_alphas.to_csv(best_alpha_csv_path, index=False)
print(f"\n✓ 已保存到: {best_alpha_csv_path}")

# 按照 best_alpha 筛选原始数据（保留所有 metric）
print("\n" + "=" * 80)
print("按照 best_alpha 筛选原始数据（保留所有指标）")
print("=" * 80)

best_alpha_data_records = []
# 获取每个 (method, size, reward_temp) 的唯一 best_alpha
for method in df_best_alphas['method'].unique():
    for size in df_best_alphas[df_best_alphas['method'] == method]['size'].unique():
        for reward_temp in df_best_alphas[(df_best_alphas['method'] == method) & (df_best_alphas['size'] == size)]['reward_temp'].unique():
            # 取该 (method, size, reward_temp) 的第一个 best_alpha
            best_alphas_for_msr = df_best_alphas[(df_best_alphas['method'] == method) & (df_best_alphas['size'] == size) & (df_best_alphas['reward_temp'] == reward_temp)]['best_alpha']
            if len(best_alphas_for_msr) > 0:
                best_alpha = best_alphas_for_msr.iloc[0]  # 取第一个
                
                # 从原始数据中筛选出该 method、size、reward_temp、alpha 的所有记录
                mask = (df_all['method'] == method) & (df_all['size'] == size) & (df_all['reward_temp'] == reward_temp) & (df_all['alpha'] == best_alpha)
                matched_rows = df_all[mask]
                
                if len(matched_rows) > 0:
                    # 计算平均和标准差
                    record = {
                        'method': method,
                        'size': size,
                        'reward_temp': reward_temp,
                        'alpha': best_alpha,
                    }
                    for m in metrics:
                        record[f'{m}_mean'] = matched_rows[m].mean()
                        record[f'{m}_std'] = matched_rows[m].std()
                    best_alpha_data_records.append(record)

df_best_alpha_data = pd.DataFrame(best_alpha_data_records)
print(df_best_alpha_data.to_string(index=False))

best_alpha_data_path = out_dir / 'best_alpha_data.csv'
df_best_alpha_data.to_csv(best_alpha_data_path, index=False)
print(f"\n✓ 已保存到: {best_alpha_data_path}")

# 保存 alpha_init=0.5 的 baseline 数据（包含均值和标准差）
print("\n" + "=" * 80)
print("Baseline 数据 (alpha_init=0.5) 的均值和标准差")
print("=" * 80)

baseline_records = []
for obj in objectives:
    for size in sizes:
        for reward_temp in reward_temps:
            df_obj = df_all[(df_all['method'] == obj) & (df_all['size'] == size) & (df_all['reward_temp'] == reward_temp) & (df_all['alpha'] == 0.5)].copy()
            if len(df_obj) > 0:
                record = {
                    'method': obj,
                    'size': size,
                    'reward_temp': reward_temp,
                    'alpha': 0.5,
                }
                for m in metrics:
                    record[f'{m}_mean'] = df_obj[m].mean()
                    record[f'{m}_std'] = df_obj[m].std()
                baseline_records.append(record)

df_baseline = pd.DataFrame(baseline_records)
if len(df_baseline) > 0:
    print(df_baseline.to_string(index=False))
    baseline_path = out_dir / 'baseline_alpha0.5_data.csv'
    df_baseline.to_csv(baseline_path, index=False)
    print(f"\n✓ 已保存到: {baseline_path}")
else:
    print("没有找到 alpha=0.5 的数据")
# Out:
# ================================================================================
# 最优 Alpha 汇总
# ================================================================================
#    method   size  reward_temp                   metric  best_alpha   best_value
#    db_gfn  large          0.5                    modes         0.9 7.863130e+04
#    db_gfn  large          0.5          mean_top_1000_R         0.9 3.774861e+11
#    db_gfn  large          0.5 mean_top_1000_similarity         0.9 8.870854e-01
#    db_gfn  large          0.5       spearman_corr_test         0.9 9.749071e-01
#    db_gfn  large          1.0                    modes         0.9 3.558000e+02
#    db_gfn  large          1.0          mean_top_1000_R         0.9 6.247218e+05
#    db_gfn  large          1.0 mean_top_1000_similarity         0.9 8.829445e-01
#    db_gfn  large          1.0       spearman_corr_test         0.9 9.445150e-01
#    db_gfn  large          2.0                    modes         0.9 3.770000e+01
#    db_gfn  large          2.0          mean_top_1000_R         0.9 2.244479e+05
#    db_gfn  large          2.0 mean_top_1000_similarity         0.9 8.582229e-01
#    db_gfn  large          2.0       spearman_corr_test         0.9 8.370537e-01
#    db_gfn medium          0.5                    modes         0.9 7.822310e+04
#    db_gfn medium          0.5          mean_top_1000_R         0.9 2.499582e+11
#    db_gfn medium          0.5 mean_top_1000_similarity         0.9 8.205025e-01
#    db_gfn medium          0.5       spearman_corr_test         0.9 9.889062e-01
#    db_gfn medium          1.0                    modes         0.9 3.140000e+01
#    db_gfn medium          1.0          mean_top_1000_R         0.9 5.520201e+05
#    db_gfn medium          1.0 mean_top_1000_similarity         0.9 8.034897e-01
#    db_gfn medium          1.0       spearman_corr_test         0.9 9.726776e-01
#    db_gfn medium          2.0                    modes         0.9 3.000000e+00
#    db_gfn medium          2.0          mean_top_1000_R         0.9 2.347011e+05
#    db_gfn medium          2.0 mean_top_1000_similarity         0.9 8.001669e-01
#    db_gfn medium          2.0       spearman_corr_test         0.9 9.310805e-01
#    db_gfn  small          0.5                    modes         0.9 4.500000e+01
#    db_gfn  small          0.5          mean_top_1000_R         0.9 1.354104e-01
#    db_gfn  small          0.5 mean_top_1000_similarity         0.9 7.383234e-01
#    db_gfn  small          0.5       spearman_corr_test         0.9 9.968651e-01
#    db_gfn  small          1.0                    modes         0.9 5.580000e+01
#    db_gfn  small          1.0          mean_top_1000_R         0.9 2.043800e-01
#    db_gfn  small          1.0 mean_top_1000_similarity         0.9 7.208810e-01
#    db_gfn  small          1.0       spearman_corr_test         0.9 9.952736e-01
#    db_gfn  small          2.0                    modes         0.9 2.335100e+03
#    db_gfn  small          2.0          mean_top_1000_R         0.9 2.750035e-01
#    db_gfn  small          2.0 mean_top_1000_similarity         0.9 6.722497e-01
#    db_gfn  small          2.0       spearman_corr_test         0.9 9.860355e-01
# fl_db_gfn  large          0.5                    modes         0.9 8.638670e+04
# fl_db_gfn  large          0.5          mean_top_1000_R         0.9 3.835655e+11
# fl_db_gfn  large          0.5 mean_top_1000_similarity         0.9 9.003651e-01
# fl_db_gfn  large          0.5       spearman_corr_test         0.9 7.163444e-01
# fl_db_gfn  large          1.0                    modes         0.9 2.239200e+03
# fl_db_gfn  large          1.0          mean_top_1000_R         0.9 7.685446e+05
# fl_db_gfn  large          1.0 mean_top_1000_similarity         0.9 8.747602e-01
# fl_db_gfn  large          1.0       spearman_corr_test         0.9 8.471801e-01
# fl_db_gfn  large          2.0                    modes         0.9 2.870000e+01
# fl_db_gfn  large          2.0          mean_top_1000_R         0.9 2.363874e+05
# fl_db_gfn  large          2.0 mean_top_1000_similarity         0.9 8.500545e-01
# fl_db_gfn  large          2.0       spearman_corr_test         0.9 9.487442e-01
# fl_db_gfn medium          0.5                    modes         0.9 8.233680e+04
# fl_db_gfn medium          0.5          mean_top_1000_R         0.9 3.810110e+11
# fl_db_gfn medium          0.5 mean_top_1000_similarity         0.9 8.871218e-01
# fl_db_gfn medium          0.5       spearman_corr_test         0.9 7.471151e-01
# fl_db_gfn medium          1.0                    modes         0.9 1.186000e+02
# fl_db_gfn medium          1.0          mean_top_1000_R         0.9 6.386881e+05
# fl_db_gfn medium          1.0 mean_top_1000_similarity         0.9 8.057597e-01
# fl_db_gfn medium          1.0       spearman_corr_test         0.9 9.349651e-01
# fl_db_gfn medium          2.0                    modes         0.9 2.200000e+00
# fl_db_gfn medium          2.0          mean_top_1000_R         0.9 2.295474e+05
# fl_db_gfn medium          2.0 mean_top_1000_similarity         0.9 7.790972e-01
# fl_db_gfn medium          2.0       spearman_corr_test         0.9 9.876454e-01
# fl_db_gfn  small          0.5                    modes         0.9 4.500000e+01
# fl_db_gfn  small          0.5          mean_top_1000_R         0.9 1.353848e-01
# fl_db_gfn  small          0.5 mean_top_1000_similarity         0.9 7.382785e-01
# fl_db_gfn  small          0.5       spearman_corr_test         0.9 8.363636e-01
# fl_db_gfn  small          1.0                    modes         0.9 8.860000e+01
# fl_db_gfn  small          1.0          mean_top_1000_R         0.9 2.199557e-01
# fl_db_gfn  small          1.0 mean_top_1000_similarity         0.9 7.371031e-01
# fl_db_gfn  small          1.0       spearman_corr_test         0.9 9.746676e-01
# fl_db_gfn  small          2.0                    modes         0.9 9.628900e+03
# fl_db_gfn  small          2.0          mean_top_1000_R         0.9 3.368589e-01
# fl_db_gfn  small          2.0 mean_top_1000_similarity         0.9 7.321099e-01
# fl_db_gfn  small          2.0       spearman_corr_test         0.9 9.905078e-01
#    tb_gfn  large          0.5                    modes         0.7 6.641970e+04
#    tb_gfn  large          0.5          mean_top_1000_R         0.7 1.202753e+11
#    tb_gfn  large          0.5 mean_top_1000_similarity         0.7 8.378997e-01
#    tb_gfn  large          0.5       spearman_corr_test         0.7 9.896351e-01
#    tb_gfn  large          1.0                    modes         0.7 5.916000e+02
#    tb_gfn  large          1.0          mean_top_1000_R         0.7 6.837025e+05
#    tb_gfn  large          1.0 mean_top_1000_similarity         0.7 8.685233e-01
#    tb_gfn  large          1.0       spearman_corr_test         0.7 9.961339e-01
#    tb_gfn  large          2.0                    modes         0.7 2.000000e-01
#    tb_gfn  large          2.0          mean_top_1000_R         0.7 9.588313e+04
#    tb_gfn  large          2.0 mean_top_1000_similarity         0.7 8.779602e-01
#    tb_gfn  large          2.0       spearman_corr_test         0.7 9.975706e-01
#    tb_gfn medium          0.5                    modes         0.8 7.883860e+04
#    tb_gfn medium          0.5          mean_top_1000_R         0.8 3.430234e+11
#    tb_gfn medium          0.5 mean_top_1000_similarity         0.8 8.570287e-01
#    tb_gfn medium          0.5       spearman_corr_test         0.8 9.937348e-01
#    tb_gfn medium          1.0                    modes         0.8 4.990000e+02
#    tb_gfn medium          1.0          mean_top_1000_R         0.8 7.039044e+05
#    tb_gfn medium          1.0 mean_top_1000_similarity         0.8 8.577053e-01
#    tb_gfn medium          1.0       spearman_corr_test         0.8 8.616766e-01
#    tb_gfn medium          2.0                    modes         0.8 8.000000e+00
#    tb_gfn medium          2.0          mean_top_1000_R         0.8 2.384823e+05
#    tb_gfn medium          2.0 mean_top_1000_similarity         0.8 8.773432e-01
#    tb_gfn medium          2.0       spearman_corr_test         0.8 9.875346e-01
#    tb_gfn  small          0.5                    modes         0.7 4.500000e+01
#    tb_gfn  small          0.5          mean_top_1000_R         0.7 1.354287e-01
#    tb_gfn  small          0.5 mean_top_1000_similarity         0.7 7.383498e-01
#    tb_gfn  small          0.5       spearman_corr_test         0.7 9.989032e-01
#    tb_gfn  small          1.0                    modes         0.7 2.480000e+01
#    tb_gfn  small          1.0          mean_top_1000_R         0.7 1.840351e-01
#    tb_gfn  small          1.0 mean_top_1000_similarity         0.7 6.936670e-01
#    tb_gfn  small          1.0       spearman_corr_test         0.7 9.993320e-01
#    tb_gfn  small          2.0                    modes         0.7 1.460500e+03
#    tb_gfn  small          2.0          mean_top_1000_R         0.7 2.457555e-01
#    tb_gfn  small          2.0 mean_top_1000_similarity         0.7 6.458165e-01
#    tb_gfn  small          2.0       spearman_corr_test         0.7 9.994471e-01
#
# ✓ 已保存到: side_product\best_alphas_summary.csv
#
# ================================================================================
# 按照 best_alpha 筛选原始数据（保留所有指标）
# ================================================================================
#    method   size  reward_temp  alpha  modes_mean    modes_std  mean_top_1000_R_mean  mean_top_1000_R_std  mean_top_1000_similarity_mean  mean_top_1000_similarity_std  spearman_corr_test_mean  spearman_corr_test_std
#    tb_gfn  large          1.0    0.5         0.0     0.000000          1.175428e+04         2.309087e+02                       0.736443                      0.000322                 0.995855                0.000449
#    tb_gfn  large          2.0    0.5         0.0     0.000000          8.503991e+02         8.569595e+02                       0.711691                      0.000146                 0.997108                0.000286
#    tb_gfn medium          0.5    0.5     54155.4 57085.019477          3.989278e+10         4.207746e+10                       0.737038                      0.000515                 0.996285                0.000728
#    tb_gfn medium          1.0    0.5         0.0     0.000000          4.485441e+04         1.480967e+03                       0.691062                      0.000837                 0.997923                0.000459
#    tb_gfn medium          2.0    0.5         0.0     0.000000          3.964936e+03         4.099779e+03                       0.660433                      0.000496                 0.998343                0.000332
#    tb_gfn  small          0.5    0.5        43.3    45.668005          1.340663e-01         9.009849e-02                       0.735912                      0.000436                 0.999275                0.000151
#    tb_gfn  small          1.0    0.5        23.2     2.387467          1.799051e-01         1.319312e-03                       0.689238                      0.001323                 0.999477                0.000179
#    tb_gfn  small          2.0    0.5      1428.3  1500.542794          2.447906e-01         1.205675e-01                       0.645166                      0.001557                 0.999441                0.000114
#
# ✓ 已保存到: side_product\baseline_alpha0.5_data.csv

# %%
# 合并 best_alpha_data 和 baseline_data
print("\n" + "=" * 80)
print("合并最优 Alpha 和 Baseline 数据")
print("=" * 80)

df_combined = pd.concat([df_best_alpha_data, df_baseline], ignore_index=True)

# 按照 method、size、alpha 排序
df_combined = df_combined.sort_values(['method', 'size', 'alpha']).reset_index(drop=True)

print(df_combined.to_string(index=False))
import os
os.makedirs('results', exist_ok=True)

combined_path = Path('results') / 'data.csv'
df_combined.to_csv(combined_path, index=False)
print(f"\n✓ 已保存到: {combined_path}")
# Out:
# ================================================================================
# 合并最优 Alpha 和 Baseline 数据
# ================================================================================
#    method   size  reward_temp  alpha  modes_mean    modes_std  mean_top_1000_R_mean  mean_top_1000_R_std  mean_top_1000_similarity_mean  mean_top_1000_similarity_std  spearman_corr_test_mean  spearman_corr_test_std
#    db_gfn  large          0.5    0.5     74813.7 78825.037981          9.964607e+10         1.053184e+11                       0.832313                      0.001589                 0.990223                0.001832
#    db_gfn  large          1.0    0.5         0.0     0.000000          5.808654e+04         5.216945e+03                       0.763214                      0.001974                 0.984226                0.003840
#    db_gfn  large          2.0    0.5         0.0     0.000000          2.214609e+03         2.276501e+03                       0.721983                      0.000467                 0.962783                0.003885
#    db_gfn  large          0.5    0.9     78631.3 73726.531385          3.774861e+11         3.980545e+11                       0.887085                      0.003361                 0.974907                0.006359
#    db_gfn  large          1.0    0.9       355.8   319.840116          6.247218e+05         5.533688e+04                       0.882944                      0.006609                 0.944515                0.004377
#    db_gfn  large          2.0    0.9        37.7   100.999505          2.244479e+05         2.475784e+05                       0.858223                      0.008224                 0.837054                0.034864
#    db_gfn medium          0.5    0.5     77080.8 81228.896949          1.419974e+11         1.498393e+11                       0.782948                      0.001787                 0.995319                0.000858
#    db_gfn medium          1.0    0.5         0.0     0.000000          1.104274e+05         5.337251e+03                       0.710264                      0.001300                 0.992868                0.004152
#    db_gfn medium          2.0    0.5         0.0     0.000000          5.482109e+03         5.689116e+03                       0.665284                      0.000614                 0.982484                0.006948
