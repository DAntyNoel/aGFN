# %%
import pandas as pd
import wandb
import json
api = wandb.Api()
runs = api.runs("1969773923-shanghai-jiao-tong-university/Refactored-Alpha-GFN-Mols-New")

cnt = 0
for run in runs:
    if run.summary.get('step', -1) == 49999 and \
       True:
        print(run.name)
        cnt += 1
cnt
# Out:
# m(db)_a(0.5)_s(1)_v(False)
# m(fl_db)_a(0.7)_s(3)_v(False)
# m(db)_a(0.8)_s(2)_v(False)
# m(db)_a(0.2)_s(1)_v(False)
# m(db)_a(0.9)_s(4)_v(False)
# m(db)_a(0.7)_s(1)_v(False)
# m(db)_a(0.6)_s(1)_v(False)
# m(db)_a(0.1)_s(2)_v(False)
# m(db)_a(0.2)_s(0)_v(False)
# m(db)_a(0.4)_s(2)_v(False)
# m(db)_a(0.4)_s(3)_v(False)
# m(fl_db)_a(0.5)_s(4)_v(False)
# m(fl_db)_a(0.6)_s(2)_v(False)
# m(fl_db)_a(0.7)_s(0)_v(False)
# m(db)_a(0.4)_s(4)_v(False)
# m(fl_db)_a(0.5)_s(2)_v(False)
# m(fl_db)_a(0.2)_s(0)_v(False)
# m(fl_db)_a(0.4)_s(1)_v(False)
# m(fl_db)_a(0.8)_s(1)_v(False)
# m(fl_db)_a(0.5)_s(0)_v(False)
# m(fl_db)_a(0.6)_s(3)_v(False)
# m(fl_db)_a(0.2)_s(2)_v(False)
# m(db)_a(0.8)_s(3)_v(False)
# m(db)_a(0.2)_s(3)_v(False)
# m(db)_a(0.6)_s(4)_v(False)
# m(fl_db)_a(0.1)_s(0)_v(False)
# m(db)_a(0.5)_s(0)_v(False)
# m(db)_a(0.2)_s(2)_v(False)
# m(fl_db)_a(0.7)_s(2)_v(False)
# m(fl_db)_a(0.4)_s(4)_v(False)
# m(fl_db)_a(0.2)_s(4)_v(False)
# m(fl_db)_a(0.3)_s(4)_v(False)
# m(db)_a(0.9)_s(2)_v(False)
# m(db)_a(0.3)_s(3)_v(False)
# m(db)_a(0.5)_s(4)_v(False)
# m(fl_db)_a(0.3)_s(3)_v(False)
# m(db)_a(0.3)_s(2)_v(False)
# m(fl_db)_a(0.1)_s(1)_v(False)
# m(fl_db)_a(0.5)_s(3)_v(False)
# m(db)_a(0.4)_s(1)_v(False)
# m(db)_a(0.2)_s(4)_v(False)
# m(db)_a(0.9)_s(3)_v(False)
# m(fl_db)_a(0.3)_s(2)_v(False)
# m(fl_db)_a(0.2)_s(1)_v(False)
# m(db)_a(0.9)_s(1)_v(False)
# m(db)_a(0.4)_s(0)_v(False)
# m(fl_db)_a(0.2)_s(3)_v(False)
# m(fl_db)_a(0.8)_s(4)_v(False)
# m(db)_a(0.6)_s(0)_v(False)
# m(db)_a(0.8)_s(0)_v(False)
# m(fl_db)_a(0.4)_s(3)_v(False)
# m(db)_a(0.3)_s(4)_v(False)
# m(db)_a(0.5)_s(2)_v(False)
# m(db)_a(0.8)_s(4)_v(False)
# m(db)_a(0.7)_s(0)_v(False)
# m(fl_db)_a(0.7)_s(4)_v(False)
# m(fl_db)_a(0.6)_s(1)_v(False)
# m(fl_db)_a(0.1)_s(2)_v(False)
# m(fl_db)_a(0.1)_s(4)_v(False)
# m(db)_a(0.3)_s(1)_v(False)
# m(fl_db)_a(0.4)_s(2)_v(False)
# m(fl_db)_a(0.1)_s(3)_v(False)
# m(fl_db)_a(0.3)_s(0)_v(False)
# m(fl_db)_a(0.6)_s(0)_v(False)
# m(fl_db)_a(0.5)_s(1)_v(False)
# m(fl_db)_a(0.7)_s(1)_v(False)
# m(fl_db)_a(0.6)_s(4)_v(False)
# m(fl_db)_a(0.4)_s(0)_v(False)
# m(db)_a(0.3)_s(0)_v(False)
# m(fl_db)_a(0.3)_s(1)_v(False)
# m(db)_a(0.8)_s(1)_v(False)
# m(db)_a(0.7)_s(2)_v(False)
# m(db)_a(0.9)_s(0)_v(False)
# m(subtb)_a(0.3)_s(2)_v(False)
# m(subtb)_a(0.4)_s(0)_v(False)
# m(subtb)_a(0.3)_s(0)_v(False)
# m(subtb)_a(0.5)_s(0)_v(False)
# m(subtb)_a(0.5)_s(2)_v(False)
# m(subtb)_a(0.4)_s(4)_v(False)
# m(subtb)_a(0.5)_s(4)_v(False)
# m(subtb)_a(0.3)_s(3)_v(False)
# m(subtb)_a(0.5)_s(1)_v(False)
# m(subtb)_a(0.3)_s(4)_v(False)
# m(subtb)_a(0.4)_s(3)_v(False)
# m(subtb)_a(0.3)_s(1)_v(False)
# m(subtb)_a(0.5)_s(3)_v(False)
# m(subtb)_a(0.4)_s(2)_v(False)
# m(subtb)_a(0.4)_s(1)_v(False)
# m(subtb)_a(0.6)_s(1)_v(False)
# m(fl_subtb)_a(0.2)_s(0)_v(False)
# m(subtb)_a(0.7)_s(1)_v(False)
# m(subtb)_a(0.7)_s(0)_v(False)
# m(subtb)_a(0.9)_s(4)_v(False)
# m(subtb)_a(0.8)_s(4)_v(False)
# m(fl_subtb)_a(0.1)_s(1)_v(False)
# m(fl_subtb)_a(0.1)_s(2)_v(False)
# m(fl_subtb)_a(0.1)_s(3)_v(False)
# m(subtb)_a(0.7)_s(2)_v(False)
# m(fl_subtb)_a(0.2)_s(4)_v(False)
# m(fl_subtb)_a(0.1)_s(4)_v(False)
# m(subtb)_a(0.9)_s(2)_v(False)
# m(fl_subtb)_a(0.2)_s(2)_v(False)
# m(fl_subtb)_a(0.2)_s(1)_v(False)
# m(subtb)_a(0.7)_s(4)_v(False)
# m(fl_db)_a(0.9)_s(3)_v(False)
# m(subtb)_a(0.9)_s(1)_v(False)
# m(fl_subtb)_a(0.1)_s(0)_v(False)
# m(fl_subtb)_a(0.2)_s(3)_v(False)
# m(fl_db)_a(0.9)_s(4)_v(False)
# m(subtb)_a(0.8)_s(3)_v(False)
# m(subtb)_a(0.8)_s(1)_v(False)
# m(subtb)_a(0.9)_s(0)_v(False)
# m(subtb)_a(0.6)_s(2)_v(False)
# m(subtb)_a(0.6)_s(0)_v(False)
# m(subtb)_a(0.8)_s(0)_v(False)
# m(subtb)_a(0.9)_s(3)_v(False)
# m(fl_db)_a(0.9)_s(1)_v(False)
# m(subtb)_a(0.6)_s(3)_v(False)
# m(fl_db)_a(0.9)_s(2)_v(False)
# m(subtb)_a(0.6)_s(4)_v(False)
# m(fl_db)_a(0.9)_s(0)_v(False)
# m(subtb)_a(0.8)_s(2)_v(False)
# m(subtb)_a(0.7)_s(3)_v(False)
# m(tb)_a(0.3)_s(3)_v(False)
# m(tb)_a(0.9)_s(4)_v(False)
# m(tb)_a(0.8)_s(1)_v(False)
# m(tb)_a(0.3)_s(1)_v(False)
# m(tb)_a(0.9)_s(0)_v(False)
# m(tb)_a(0.8)_s(0)_v(False)
# m(tb)_a(0.8)_s(3)_v(False)
# m(tb)_a(0.8)_s(2)_v(False)
# m(tb)_a(0.9)_s(1)_v(False)
# m(tb)_a(0.8)_s(4)_v(False)
# m(fl_subtb)_a(0.5)_s(3)_v(False)
# m(fl_subtb)_a(0.4)_s(1)_v(False)
# m(db)_a(0.1)_s(3)_v(False)
# m(fl_db)_a(0.8)_s(2)_v(False)
# m(fl_subtb)_a(0.7)_s(0)_v(False)
# m(db)_a(0.5)_s(3)_v(False)
# m(fl_subtb)_a(0.5)_s(2)_v(False)
# m(fl_db)_a(0.8)_s(0)_v(False)
# m(fl_subtb)_a(0.5)_s(0)_v(False)
# m(fl_subtb)_a(0.4)_s(2)_v(False)
# m(fl_subtb)_a(0.4)_s(4)_v(False)
# m(db)_a(0.7)_s(4)_v(False)
# m(fl_subtb)_a(0.7)_s(3)_v(False)
# m(fl_subtb)_a(0.4)_s(0)_v(False)
# m(fl_subtb)_a(0.5)_s(1)_v(False)
# m(fl_subtb)_a(0.7)_s(2)_v(False)
# m(fl_subtb)_a(0.6)_s(4)_v(False)
# m(db)_a(0.7)_s(3)_v(False)
# m(fl_subtb)_a(0.5)_s(4)_v(False)
# m(fl_subtb)_a(0.6)_s(2)_v(False)
# m(fl_subtb)_a(0.6)_s(1)_v(False)
# m(db)_a(0.6)_s(3)_v(False)
# m(fl_subtb)_a(0.7)_s(1)_v(False)
# m(fl_subtb)_a(0.6)_s(0)_v(False)
# m(db)_a(0.6)_s(2)_v(False)
# m(fl_db)_a(0.8)_s(3)_v(False)
# m(fl_subtb)_a(0.4)_s(3)_v(False)
# m(db)_a(0.1)_s(4)_v(False)
# m(fl_subtb)_a(0.7)_s(4)_v(False)
# m(fl_subtb)_a(0.8)_s(1)_v(False)
# m(fl_subtb)_a(0.8)_s(3)_v(False)
# m(fl_subtb)_a(0.8)_s(0)_v(False)
# m(fl_subtb)_a(0.8)_s(4)_v(False)
# m(fl_subtb)_a(0.8)_s(2)_v(False)
# m(tb)_a(0.2)_s(4)_v(False)
# m(tb)_a(0.2)_s(2)_v(False)
# m(tb)_a(0.1)_s(4)_v(False)
# m(fl_subtb)_a(0.9)_s(1)_v(False)
# m(tb)_a(0.4)_s(2)_v(False)
# m(tb)_a(0.2)_s(0)_v(False)
# m(fl_subtb)_a(0.9)_s(3)_v(False)
# m(tb)_a(0.4)_s(4)_v(False)
# m(tb)_a(0.1)_s(0)_v(False)
# m(tb)_a(0.4)_s(1)_v(False)
# m(tb)_a(0.1)_s(1)_v(False)
# m(tb)_a(0.4)_s(3)_v(False)
# m(tb)_a(0.1)_s(2)_v(False)
# m(tb)_a(0.2)_s(3)_v(False)
# m(tb)_a(0.2)_s(1)_v(False)
# m(fl_subtb)_a(0.9)_s(4)_v(False)
# m(fl_subtb)_a(0.9)_s(0)_v(False)
# m(fl_subtb)_a(0.9)_s(2)_v(False)
# m(tb)_a(0.4)_s(0)_v(False)
# m(tb)_a(0.7)_s(3)_v(False)
# m(tb)_a(0.5)_s(0)_v(False)
# m(tb)_a(0.7)_s(1)_v(False)
# m(tb)_a(0.5)_s(1)_v(False)
# m(tb)_a(0.5)_s(4)_v(False)
# m(tb)_a(0.5)_s(3)_v(False)
# m(tb)_a(0.7)_s(0)_v(False)
# m(tb)_a(0.7)_s(2)_v(False)
# m(subtb)_a(0.2)_s(1)_v(False)
# m(subtb)_a(0.2)_s(2)_v(False)
# m(subtb)_a(0.2)_s(3)_v(False)
# m(subtb)_a(0.1)_s(1)_v(False)
# m(subtb)_a(0.1)_s(0)_v(False)
# m(subtb)_a(0.1)_s(3)_v(False)
# m(subtb)_a(0.1)_s(2)_v(False)
# m(subtb)_a(0.2)_s(4)_v(False)
# m(subtb)_a(0.2)_s(0)_v(False)
# m(subtb)_a(0.1)_s(4)_v(False)
# m(fl_subtb)_a(0.3)_s(1)_v(False)
# m(fl_subtb)_a(0.6)_s(3)_v(False)
# m(db)_a(0.1)_s(5)_v(False)
# m(tb)_a(0.9)_s(2)_v(False)
# m(tb)_a(0.6)_s(4)_v(False)
# m(tb)_a(0.9)_s(3)_v(False)
# m(tb)_a(0.6)_s(3)_v(False)
# m(tb)_a(0.6)_s(2)_v(False)
# m(fl_subtb)_a(0.3)_s(3)_v(False)
# m(tb)_a(0.6)_s(0)_v(False)
# m(tb)_a(0.3)_s(4)_v(False)
# m(fl_subtb)_a(0.3)_s(0)_v(False)
# m(tb)_a(0.3)_s(0)_v(False)
# m(fl_subtb)_a(0.3)_s(2)_v(False)
# m(fl_subtb)_a(0.3)_s(4)_v(False)
# m(tb)_a(0.7)_s(4)_v(False)
# m(tb)_a(0.5)_s(2)_v(False)
# m(tb)_a(0.3)_s(2)_v(False)
# m(tb)_a(0.6)_s(1)_v(False)
# m(db)_a(0.1)_s(1)_v(False)
# m(tb)_a(0.1)_s(3)_v(False)
# 225

# %%
api = wandb.Api(timeout=60)
runs = api.runs("1969773923-shanghai-jiao-tong-university/Refactored-Alpha-GFN-Mols-New")
for run in runs:
    if run.summary['step'] != 49999:
        continue
    history = run.history(pandas=False)
    break
sorted(history[0].keys()) + sorted(run.summary.keys())
# Out:
# ['_runtime',
#  '_step',
#  '_timestamp',
#  'all_samples_avg_length_eval',
#  'all_samples_avg_reward_eval',
#  'alpha',
#  'avg_current_reward_eval',
#  'avg_loss_of_last_500_steps',
#  'backward_avg_action_prob_eval',
#  'backward_policy_entropy_eval',
#  'candidates_avg_length_eval',
#  'candidates_avg_reward_eval',
#  'candidates_avg_similarity_eval',
#  'clip_scale_avg_interval',
#  'clip_trigger_rate_interval',
#  'current_loss',
#  'eval_repo_size',
#  'forward_avg_action_prob_eval',
#  'forward_policy_entropy_eval',
#  'modes_avg_length_eval',
#  'modes_avg_reward_eval',
#  'modes_avg_similarity_eval',
#  'num_candidates_above_thresh_eval',
#  'num_modes_eval',
#  'pearson_corr_test',
#  'random_action_prob',
#  'spearman_corr_test',
#  'step',
#  'top_1000_avg_length_eval',
#  'top_1000_avg_reward_eval',
#  'top_1000_avg_similarity_eval',
#  'top_1000_count_eval',
#  'top_100_avg_length_eval',
#  'top_100_avg_reward_eval',
#  'top_100_avg_similarity_eval',
#  'top_100_count_eval',
#  'top_10_avg_length_eval',
#  'top_10_avg_reward_eval',
#  'top_10_avg_similarity_eval',
#  'top_10_count_eval',
#  'top_50_avg_length_eval',
#  'top_50_avg_reward_eval',
#  'top_50_avg_similarity_eval',
#  'top_50_count_eval',
#  'R_min',
#  '_runtime',
#  '_step',
#  '_timestamp',
#  'all_samples_avg_length_eval',
#  'all_samples_avg_reward_eval',
#  'alpha',
#  'alpha_init',
#  'alpha_lr',
#  'alpha_sched',
#  'alpha_trainable',
#  'alpha_warm_frac',
#  'array',
#  'avg_current_reward_eval',
#  'avg_loss_of_last_500_steps',
#  'backward_avg_action_prob_eval',
#  'backward_policy_entropy_eval',
#  'balanced_loss',
#  'bootstrap_tau',
#  'candidates_avg_length_eval',
#  'candidates_avg_reward_eval',
#  'candidates_avg_similarity_eval',
#  'clip_grad',
#  'clip_loss',
#  'clip_scale_avg_interval',
#  'clip_trigger_rate_interval',
#  'current_loss',
#  'debug_no_threads',
#  'early_stop_reg',
#  'entropy_coeff',
#  'eps_end_frac',
#  'eps_start',
#  'eval_dedup_key',
#  'eval_every',
#  'eval_repo_size',
#  'exp_weight_sched',
#  'exp_weight_warm_frac',
#  'fl',
#  'forward_avg_action_prob_eval',
#  'forward_policy_entropy_eval',
#  'ignore_parents',
#  'include_nblocks',
#  'initial_log_Z',
#  'leaf_coef',
#  'learning_rate',
#  'log_reg_c',
#  'max_blocks',
#  'mbsize',
#  'min_blocks',
#  'mode_threshold',
#  'model_seed',
#  'model_version',
#  'modes_avg_length_eval',
#  'modes_avg_reward_eval',
#  'modes_avg_similarity_eval',
#  'nemb',
#  'num_candidates_above_thresh_eval',
#  'num_conv_steps',
#  'num_iterations',
#  'num_modes_eval',
#  'num_threads',
#  'objective',
#  'opt_alpha_interval',
#  'opt_alpha_steps',
#  'opt_beta',
#  'opt_beta2',
#  'opt_epsilon',
#  'pearson_corr_test',
#  'print_array_length',
#  'progress',
#  'proxy_path',
#  'random_action_prob',
#  'random_action_prob_final',
#  'replay_mode',
#  'repr_type',
#  'reward_exp',
#  'reward_norm',
#  'run',
#  'sample_prob',
#  'sampling_seed',
#  'save_every',
#  'save_path',
#  'spearman_corr_test',
#  'step',
#  'steps_to_update_sampling_model',
#  'subtb_lambda',
#  'tanimoto_threshold',
#  'top_1000_avg_length_eval',
#  'top_1000_avg_reward_eval',
#  'top_1000_avg_similarity_eval',
#  'top_1000_count_eval',
#  'top_100_avg_length_eval',
#  'top_100_avg_reward_eval',
#  'top_100_avg_similarity_eval',
#  'top_100_count_eval',
#  'top_10_avg_length_eval',
#  'top_10_avg_reward_eval',
#  'top_10_avg_similarity_eval',
#  'top_10_count_eval',
#  'top_50_avg_length_eval',
#  'top_50_avg_reward_eval',
#  'top_50_avg_similarity_eval',
#  'top_50_count_eval',
#  'top_k',
#  'train_first_steps',
#  'training_scheme',
#  'use_alpha_scheduler',
#  'use_exp_weight_decay',
#  'vec',
#  'wdb',
#  'wdb_name',
#  'wdb_project',
#  'weight_decay']

# %%
run.summary[
    'top_1000_avg_reward_eval'
]
history[100][
    'top_1000_avg_reward_eval'
]
# Out:
# 6.341808256515205

# %%
import time
import wandb
import json

filters = {
    'step': 49999
}

valid_keys = [
 'all_samples_avg_length_eval',
 'all_samples_avg_reward_eval',
 'alpha',
 'backward_policy_entropy_eval',
 'current_loss',
 'forward_policy_entropy_eval',
 'modes_avg_length_eval',
 'modes_avg_reward_eval',
 'modes_avg_similarity_eval',
 'num_modes_eval',
 'spearman_corr_test',
 'step',
 'top_1000_avg_reward_eval',
 'top_100_avg_reward_eval',
 'top_50_avg_reward_eval',
 'top_10_avg_reward_eval'
    # 'use_alpha_scheduler',
    # 'alpha_init',
    # 'forward_policy_entropy_test',
    # 'step',
    # 'loss',
    # 'mean_top_100_R',
    # 'mean_top_1000_R',
    # 'mean_R',
    # 'grad_clip_norm',
    # 'use_grad_clip',
    # 'modes',
    # 'method',
    # 'forward_policy_entropy_eval',
    # 'backward_policy_entropy_eval',
    # 'fl',
    # 'alpha',
    # 'spearman_corr_test'
]

sum_keys = [
 'alpha_init',
 'fl',
 'objective',
]

def summary_keys(historys, valid_keys, run_summary):
    summarized = {}
    for his in historys:
        present_keys = set(his.keys())
        # assert set(valid_keys).issubset(present_keys), f"Some valid keys are missing: {set(valid_keys) - present_keys}"
        for key in valid_keys:
            if key not in summarized:
                summarized[key] = []
            summarized[key].append(his.get(key, 'UNKNOWN'))
    # 检查是否有固定值
    for key in summarized:
        values = summarized[key]
        if all(v == values[0] for v in values[:-1]):
            summarized[key] = values[-1]
    # 添加 summary keys
    for key in sum_keys:
        if key in historys[-1]:
            summarized[key] = run_summary[key]
    return summarized


def set_filter_generator(runs, filters):
    for run in runs:
        match = True
        for key, value in filters.items():
            if key not in run.summary or run.summary[key] != value:
                match = False
                break
        if match:
            # history = fetch_history_with_retry(run)
            history = run.history(pandas=False)
            yield history, run.name, run.summary

api = wandb.Api()
runs = api.runs("1969773923-shanghai-jiao-tong-university/Refactored-Alpha-GFN-Mols-New")
ttl = {}
for history, name, sum in set_filter_generator(runs, filters):
    print(f"Processing run: {name}")
    summarized = summary_keys(history, valid_keys, sum)
    ttl[name] = summarized
with open(f"mols_run_summary.json", "w") as f:
    json.dump(ttl, f, indent=2)
print(f"Collected summaries for {len(ttl)} runs.")
# Out:
# Processing run: m(db)_a(0.5)_s(1)_v(False)
# Processing run: m(fl_db)_a(0.7)_s(3)_v(False)
# Processing run: m(db)_a(0.8)_s(2)_v(False)
# Processing run: m(db)_a(0.2)_s(1)_v(False)
# Processing run: m(db)_a(0.9)_s(4)_v(False)
# Processing run: m(db)_a(0.7)_s(1)_v(False)
# Processing run: m(db)_a(0.6)_s(1)_v(False)
# Processing run: m(db)_a(0.1)_s(2)_v(False)
# Processing run: m(db)_a(0.2)_s(0)_v(False)
# Processing run: m(db)_a(0.4)_s(2)_v(False)
# Processing run: m(db)_a(0.4)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.5)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.6)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.7)_s(0)_v(False)
# Processing run: m(db)_a(0.4)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.5)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.2)_s(0)_v(False)
# Processing run: m(fl_db)_a(0.4)_s(1)_v(False)
# Processing run: m(fl_db)_a(0.8)_s(1)_v(False)
# Processing run: m(fl_db)_a(0.5)_s(0)_v(False)
# Processing run: m(fl_db)_a(0.6)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.2)_s(2)_v(False)
# Processing run: m(db)_a(0.8)_s(3)_v(False)
# Processing run: m(db)_a(0.2)_s(3)_v(False)
# Processing run: m(db)_a(0.6)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.1)_s(0)_v(False)
# Processing run: m(db)_a(0.5)_s(0)_v(False)
# Processing run: m(db)_a(0.2)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.7)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.4)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.2)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.3)_s(4)_v(False)
# Processing run: m(db)_a(0.9)_s(2)_v(False)
# Processing run: m(db)_a(0.3)_s(3)_v(False)
# Processing run: m(db)_a(0.5)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.3)_s(3)_v(False)
# Processing run: m(db)_a(0.3)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.1)_s(1)_v(False)
# Processing run: m(fl_db)_a(0.5)_s(3)_v(False)
# Processing run: m(db)_a(0.4)_s(1)_v(False)
# Processing run: m(db)_a(0.2)_s(4)_v(False)
# Processing run: m(db)_a(0.9)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.3)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.2)_s(1)_v(False)
# Processing run: m(db)_a(0.9)_s(1)_v(False)
# Processing run: m(db)_a(0.4)_s(0)_v(False)
# Processing run: m(fl_db)_a(0.2)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.8)_s(4)_v(False)
# Processing run: m(db)_a(0.6)_s(0)_v(False)
# Processing run: m(db)_a(0.8)_s(0)_v(False)
# Processing run: m(fl_db)_a(0.4)_s(3)_v(False)
# Processing run: m(db)_a(0.3)_s(4)_v(False)
# Processing run: m(db)_a(0.5)_s(2)_v(False)
# Processing run: m(db)_a(0.8)_s(4)_v(False)
# Processing run: m(db)_a(0.7)_s(0)_v(False)
# Processing run: m(fl_db)_a(0.7)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.6)_s(1)_v(False)
# Processing run: m(fl_db)_a(0.1)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.1)_s(4)_v(False)
# Processing run: m(db)_a(0.3)_s(1)_v(False)
# Processing run: m(fl_db)_a(0.4)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.1)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.3)_s(0)_v(False)
# Processing run: m(fl_db)_a(0.6)_s(0)_v(False)
# Processing run: m(fl_db)_a(0.5)_s(1)_v(False)
# Processing run: m(fl_db)_a(0.7)_s(1)_v(False)
# Processing run: m(fl_db)_a(0.6)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.4)_s(0)_v(False)
# Processing run: m(db)_a(0.3)_s(0)_v(False)
# Processing run: m(fl_db)_a(0.3)_s(1)_v(False)
# Processing run: m(db)_a(0.8)_s(1)_v(False)
# Processing run: m(db)_a(0.7)_s(2)_v(False)
# Processing run: m(db)_a(0.9)_s(0)_v(False)
# Processing run: m(subtb)_a(0.3)_s(2)_v(False)
# Processing run: m(subtb)_a(0.4)_s(0)_v(False)
# Processing run: m(subtb)_a(0.3)_s(0)_v(False)
# Processing run: m(subtb)_a(0.5)_s(0)_v(False)
# Processing run: m(subtb)_a(0.5)_s(2)_v(False)
# Processing run: m(subtb)_a(0.4)_s(4)_v(False)
# Processing run: m(subtb)_a(0.5)_s(4)_v(False)
# Processing run: m(subtb)_a(0.3)_s(3)_v(False)
# Processing run: m(subtb)_a(0.5)_s(1)_v(False)
# Processing run: m(subtb)_a(0.3)_s(4)_v(False)
# Processing run: m(subtb)_a(0.4)_s(3)_v(False)
# Processing run: m(subtb)_a(0.3)_s(1)_v(False)
# Processing run: m(subtb)_a(0.5)_s(3)_v(False)
# Processing run: m(subtb)_a(0.4)_s(2)_v(False)
# Processing run: m(subtb)_a(0.4)_s(1)_v(False)
# Processing run: m(subtb)_a(0.6)_s(1)_v(False)
# Processing run: m(fl_subtb)_a(0.2)_s(0)_v(False)
# Processing run: m(subtb)_a(0.7)_s(1)_v(False)
# Processing run: m(subtb)_a(0.7)_s(0)_v(False)
# Processing run: m(subtb)_a(0.9)_s(4)_v(False)
# Processing run: m(subtb)_a(0.8)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.1)_s(1)_v(False)
# Processing run: m(fl_subtb)_a(0.1)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.1)_s(3)_v(False)
# Processing run: m(subtb)_a(0.7)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.2)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.1)_s(4)_v(False)
# Processing run: m(subtb)_a(0.9)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.2)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.2)_s(1)_v(False)
# Processing run: m(subtb)_a(0.7)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.9)_s(3)_v(False)
# Processing run: m(subtb)_a(0.9)_s(1)_v(False)
# Processing run: m(fl_subtb)_a(0.1)_s(0)_v(False)
# Processing run: m(fl_subtb)_a(0.2)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.9)_s(4)_v(False)
# Processing run: m(subtb)_a(0.8)_s(3)_v(False)
# Processing run: m(subtb)_a(0.8)_s(1)_v(False)
# Processing run: m(subtb)_a(0.9)_s(0)_v(False)
# Processing run: m(subtb)_a(0.6)_s(2)_v(False)
# Processing run: m(subtb)_a(0.6)_s(0)_v(False)
# Processing run: m(subtb)_a(0.8)_s(0)_v(False)
# Processing run: m(subtb)_a(0.9)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.9)_s(1)_v(False)
# Processing run: m(subtb)_a(0.6)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.9)_s(2)_v(False)
# Processing run: m(subtb)_a(0.6)_s(4)_v(False)
# Processing run: m(fl_db)_a(0.9)_s(0)_v(False)
# Processing run: m(subtb)_a(0.8)_s(2)_v(False)
# Processing run: m(subtb)_a(0.7)_s(3)_v(False)
# Processing run: m(tb)_a(0.3)_s(3)_v(False)
# Processing run: m(tb)_a(0.9)_s(4)_v(False)
# Processing run: m(tb)_a(0.8)_s(1)_v(False)
# Processing run: m(tb)_a(0.3)_s(1)_v(False)
# Processing run: m(tb)_a(0.9)_s(0)_v(False)
# Processing run: m(tb)_a(0.8)_s(0)_v(False)
# Processing run: m(tb)_a(0.8)_s(3)_v(False)
# Processing run: m(tb)_a(0.8)_s(2)_v(False)
# Processing run: m(tb)_a(0.9)_s(1)_v(False)
# Processing run: m(tb)_a(0.8)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.5)_s(3)_v(False)
# Processing run: m(fl_subtb)_a(0.4)_s(1)_v(False)
# Processing run: m(db)_a(0.1)_s(3)_v(False)
# Processing run: m(fl_db)_a(0.8)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.7)_s(0)_v(False)
# Processing run: m(db)_a(0.5)_s(3)_v(False)
# Processing run: m(fl_subtb)_a(0.5)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.8)_s(0)_v(False)
# Processing run: m(fl_subtb)_a(0.5)_s(0)_v(False)
# Processing run: m(fl_subtb)_a(0.4)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.4)_s(4)_v(False)
# Processing run: m(db)_a(0.7)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.7)_s(3)_v(False)
# Processing run: m(fl_subtb)_a(0.4)_s(0)_v(False)
# Processing run: m(fl_subtb)_a(0.5)_s(1)_v(False)
# Processing run: m(fl_subtb)_a(0.7)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.6)_s(4)_v(False)
# Processing run: m(db)_a(0.7)_s(3)_v(False)
# Processing run: m(fl_subtb)_a(0.5)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.6)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.6)_s(1)_v(False)
# Processing run: m(db)_a(0.6)_s(3)_v(False)
# Processing run: m(fl_subtb)_a(0.7)_s(1)_v(False)
# Processing run: m(fl_subtb)_a(0.6)_s(0)_v(False)
# Processing run: m(db)_a(0.6)_s(2)_v(False)
# Processing run: m(fl_db)_a(0.8)_s(3)_v(False)
# Processing run: m(fl_subtb)_a(0.4)_s(3)_v(False)
# Processing run: m(db)_a(0.1)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.7)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.8)_s(1)_v(False)
# Processing run: m(fl_subtb)_a(0.8)_s(3)_v(False)
# Processing run: m(fl_subtb)_a(0.8)_s(0)_v(False)
# Processing run: m(fl_subtb)_a(0.8)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.8)_s(2)_v(False)
# Processing run: m(tb)_a(0.2)_s(4)_v(False)
# Processing run: m(tb)_a(0.2)_s(2)_v(False)
# Processing run: m(tb)_a(0.1)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.9)_s(1)_v(False)
# Processing run: m(tb)_a(0.4)_s(2)_v(False)
# Processing run: m(tb)_a(0.2)_s(0)_v(False)
# Processing run: m(fl_subtb)_a(0.9)_s(3)_v(False)
# Processing run: m(tb)_a(0.4)_s(4)_v(False)
# Processing run: m(tb)_a(0.1)_s(0)_v(False)
# Processing run: m(tb)_a(0.4)_s(1)_v(False)
# Processing run: m(tb)_a(0.1)_s(1)_v(False)
# Processing run: m(tb)_a(0.4)_s(3)_v(False)
# Processing run: m(tb)_a(0.1)_s(2)_v(False)
# Processing run: m(tb)_a(0.2)_s(3)_v(False)
# Processing run: m(tb)_a(0.2)_s(1)_v(False)
# Processing run: m(fl_subtb)_a(0.9)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.9)_s(0)_v(False)
# Processing run: m(fl_subtb)_a(0.9)_s(2)_v(False)
# Processing run: m(tb)_a(0.4)_s(0)_v(False)
# Processing run: m(tb)_a(0.7)_s(3)_v(False)
# Processing run: m(tb)_a(0.5)_s(0)_v(False)
# Processing run: m(tb)_a(0.7)_s(1)_v(False)
# Processing run: m(tb)_a(0.5)_s(1)_v(False)
# Processing run: m(tb)_a(0.5)_s(4)_v(False)
# Processing run: m(tb)_a(0.5)_s(3)_v(False)
# Processing run: m(tb)_a(0.7)_s(0)_v(False)
# Processing run: m(tb)_a(0.7)_s(2)_v(False)
# Processing run: m(subtb)_a(0.2)_s(1)_v(False)
# Processing run: m(subtb)_a(0.2)_s(2)_v(False)
# Processing run: m(subtb)_a(0.2)_s(3)_v(False)
# Processing run: m(subtb)_a(0.1)_s(1)_v(False)
# Processing run: m(subtb)_a(0.1)_s(0)_v(False)
# Processing run: m(subtb)_a(0.1)_s(3)_v(False)
# Processing run: m(subtb)_a(0.1)_s(2)_v(False)
# Processing run: m(subtb)_a(0.2)_s(4)_v(False)
# Processing run: m(subtb)_a(0.2)_s(0)_v(False)
# Processing run: m(subtb)_a(0.1)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.3)_s(1)_v(False)
# Processing run: m(fl_subtb)_a(0.6)_s(3)_v(False)
# Processing run: m(db)_a(0.1)_s(5)_v(False)
# Processing run: m(tb)_a(0.9)_s(2)_v(False)
# Processing run: m(tb)_a(0.6)_s(4)_v(False)
# Processing run: m(tb)_a(0.9)_s(3)_v(False)
# Processing run: m(tb)_a(0.6)_s(3)_v(False)
# Processing run: m(tb)_a(0.6)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.3)_s(3)_v(False)
# Processing run: m(tb)_a(0.6)_s(0)_v(False)
# Processing run: m(tb)_a(0.3)_s(4)_v(False)
# Processing run: m(fl_subtb)_a(0.3)_s(0)_v(False)
# Processing run: m(tb)_a(0.3)_s(0)_v(False)
# Processing run: m(fl_subtb)_a(0.3)_s(2)_v(False)
# Processing run: m(fl_subtb)_a(0.3)_s(4)_v(False)
# Processing run: m(tb)_a(0.7)_s(4)_v(False)
# Processing run: m(tb)_a(0.5)_s(2)_v(False)
# Processing run: m(tb)_a(0.3)_s(2)_v(False)
# Processing run: m(tb)_a(0.6)_s(1)_v(False)
# Processing run: m(db)_a(0.1)_s(1)_v(False)
# Processing run: m(tb)_a(0.1)_s(3)_v(False)
# Collected summaries for 225 runs.
